# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np

# %%
# define url
url = 'https://www.jobberman.com/jobs/software-data?sort=featured'

# %%
#headers for request
HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0', 'Accept-Language':'en-US, en;q=0.5'})

# %%
#http request
webpage = requests.get(url, headers=HEADERS)

# %%
webpage
# Out:
# <Response [200]>

# %%
type(webpage.content)
# Out:
# bytes

# %%
#soup objects containing all data
soup = BeautifulSoup(webpage.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js scroll-smooth" lang="en-ng">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="4hClu3W3PtjepabInbxYOahjMMOlzUNqWBY9OKZJtdA" name="google-site-verification">
# <meta content="qrUfchestySaSITn85Ael8isKjJXqTZ2g3rtpuvY" name="csrf-token"/>
# <link href="https://www.jobberman.com/listings/backend-developer-evdg2j" rel="prerender"/>
# <link href="https://www.jobberman.com/listings/fullstack-web-application-developer-r82g4j" rel="prerender"/>
# <link href="https://www.jobberman.com/listings/software-engineer-pythondjango-9j0e4w" rel="prerender"/>
# <link href="https://www.jobberman.com/listings/website-administrative-xpdnmq" rel="prerender"/>
# <link href="https://www.jobberman.com/listings/software-engineering-manager-isw-principal-engineer-vwmq2v" rel="prerender"/>
# <link href="https://www.jobberman.com/listings/web-development-coding-teacher-r820mg" rel="prerender"/>
# <link href="https://www.jobberman.com/listings/full-stack-developer-840dr6" rel="prerender"/>
# <link href="https://www.jobberman.com/listings/remote-data-collection-and-data-entry-specialist-project-waterbury-840dx6" rel="prerender"/>
# <link href="https://www.jobberman.com/listings/business-systems-integration-lead-7w8vdg" rel="prerender"/>
# <link href="https://www.jobberman.com/listings/developer-software-developmentinformation-technology-84v0g4" rel="prerender"/>
# <link href="https://www.jobberman.com/listings/data-scientistenterprise-business-ng-zpv2j9" rel="prerender"/>
# <link href="https://www.jobberman.com/listings/cta-2-k8rmx2" rel="prerender"/>
# <link href="https://www.jobberman.com/listings/quality-assurance-qa-engineer-gwq548" rel="prerender"/>
# <link href="https://www.jobberman.com/listings/data-science-tutorinstructor-vw4mdk" rel="prerender"/>
# <link href="https://www.jobberman.com/listings/business-analyst-5d6wpx" rel="prerender"/>
# <link href="https://www.jobberman.com/listings/senior-data-analyst-pmdpgp" rel="prerender"/>
# <link href="https://user-img-ng-jobs-prod/" rel="dns-prefetch"/>
# <link href="https://advertiser-img-ng-jobs-prod/" rel="dns-prefetch"/>
# <link href="https://www.googletagmanager.com/" rel="dns-prefetch"/>
# <link href="https://www.google-analytics.com/" rel="dns-prefetch"/>
# <link href="https://www.googletagmanager.com/" rel="preconnect"/>
# <link href="https://www.google-analytics.com/" rel="preconnect"/>
# <link href="https://script.hotjar.com/" rel="dns-prefetch"/>
# <link href="https://static.hotjar.com/" rel="dns-prefetch"/>
# <link href="https://vars.hotjar.com/" rel="dns-prefetch"/>
# <link href="https://www.googleadservices.com/" rel="dns-prefetch"/>
# <link href="https://bam.nr-data.com/" rel="dns-prefetch"/>
# <link as="font" crossorigin="anonymous" href="/build/static-assets/fonts/inter-v11-latin-300.c1621953.woff2" rel="preload"/>
# <link as="font" crossorigin="anonymous" href="/build/static-assets/fonts/inter-v11-latin-regular.3a92ec24.woff2" rel="preload"/>
# <link as="font" crossorigin="anonymous" href="/build/static-assets/fonts/inter-v11-latin-500.03a0aa43.woff2" rel="preload"/>
# <link as="font" crossorigin="anonymous" href="/build/static-assets/fonts/inter-v11-latin-700.28198516.woff2" rel="preload"/>
# <link href="https://www.jobberman.com/jobs/software-data" rel="canonical"><link href="https://www.jobberman.com/jobs/software-data?sort=featured&amp;page=2" rel="next"><link href="android-app://com.jobberman/search?domain=ng&amp;job_function_ids%5B0%5D=27" rel="alternate">
# <meta content="INDEX,FOLLOW" name="robots"/>
# <title>Software &amp; Data Jobs in Nigeria | Jobberman</title>
# <meta content="Find Software &amp; Data | job vacancies from top companies and employers. Easily apply online or sign up for the latest job alerts" name="description">
# <meta content="Software &amp; Data Jobs" property="og:title">
# <meta content="Easily apply online or sign up for job alerts" property="og:description"/>
# <meta content="https://i.roamcdn.net/t/kazi/ng/og-template-1200w-630h/58dd684110e5272d6dc20126b7bae8a2/-%3D/software-data-jobs-in-nigeria.jpg" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="630" property="og:image:height"/>
# <meta content="Find a job" property="og:image:alt"/>
# <meta content="Jobberman" property="og:site_name"/>
# <meta content="Website" property="og:type"/>
# <meta content="2023-11-18T00:00:00+00:00" property="og:updated_time"/>
# <meta content="https://www.jobberman.com/jobs/software-data" property="og:url"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="Software &amp; Data Jobs" name="twitter:title"/>
# <meta content="Easily apply online or sign up for job alerts" name="twitter:description"/>
# <meta content="https://i.roamcdn.net/t/kazi/ng/og-template-1200w-630h/58dd684110e5272d6dc20126b7bae8a2/-%3D/software-data-jobs-in-nigeria.jpg" name="twitter:image"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="URL_BM_Nigeria" property="banner-targeting-key"/>
# <meta content="" property="banner-targeting-value"/>
# <meta content="," name="sailthru.tags"/>
# <meta content="189313221529" property="fb:app_id">
# <link href="/build/static-assets/favicon/jobberman/apple-touch-icon.e95ca53c.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/build/static-assets/favicon/jobberman/favicon-32x32.b3c705e3.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/build/static-assets/favicon/jobberman/favicon-16x16.3986e307.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/build/static-assets/favicon/jobberman/manifest.a6626b21.json" rel="manifest"/>
# <link color="#4168C6" href="/build/static-assets/favicon/jobberman/safari-pinned-tab.74493a88.svg" rel="mask-icon"/>
# <link href="/build/static-assets/favicon/jobberman/favicon.3354dcb2.ico" rel="shortcut icon" sizes="any"/>
# <link href="/build/static-assets/favicon/jobberman/favicon.3989c8ed.svg" rel="icon" type="image/svg+xml"/>
# <meta content="#4168C6" name="msapplication-TileColor"/>
# <meta content="/build/static-assets/favicon/jobberman/browserconfig.24e6b14c.xml" name="msapplication-config"/>
# <meta content="/" name="msapplication-starturl"/>
# <meta content="#4168C6" name="theme-color"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <link as="style" href="/build/assets/css/jobberman/fonts.3a1ef93d.css" rel="preload">
# <link href="/build/assets/css/jobberman/fonts.3a1ef93d.css" rel="stylesheet">
# <link as="style" href="/build/assets/css/jobberman/tailwindcss-v3.4cdcd119.css" rel="preload">
# <link href="/build/assets/css/jobberman/tailwindcss-v3.4cdcd119.css" rel="stylesheet">
# <script>
#         document.documentElement.className = document.documentElement.className.replace("no-js", "js");
#
#         if (
#             (
#                 typeof window.operamini !== "undefined"
#                 && window.operamini
#             )
#             || navigator.userAgent.indexOf("Opera Mini/") > -1
#         ) {
#             document.documentElement.className += " opera-mini-mode";
#         }
#     </script>
# <script charset="UTF-8" data-domain-script="42db4c75-a53a-4bda-a784-8baa79be307d" src="https://cdn.cookielaw.org/consent/42db4c75-a53a-4bda-a784-8baa79be307d/otSDKStub.js" type="text/javascript"></script>
# <script type="text/javascript">
#             function OptanonWrapper() { }
#         </script>
# <script>
#         window.dataLayer = window.dataLayer || [];
#         dataLayer = [{"domain_code":"ng","brand":null,"env":"production","route_name":"search.landing","version":"master-3718","session_hash":"18681d3eb2926c3cee20bdf26c3813a0","timestamp":1700288736,"event":"set_page_data","currency":"NGN","location_name":null,"category_name":"Software & Data","category_slug":"software-data","listing_ids":[947420,946976,946692,943655,942802],"user_registration_status":"","locale":"en_ng","cat_url":"\/jobs\/software-data?sort=featured&utm_medium=push&utm_source=browser&utm_campaign=return-category","keyword":"\/jobs\/software-data","search_title":"Software & data jobs in Nigeria","content_type":"classified search results","item_list_id":"c4fbc4e4b45ca003004c2ea6adbb48fb"}];
#             </script>
# <script>
#         (function(w,d,s,l,i){
#             w[l] = w[l] || [];
#             w[l].push(
#                 {
#                     'gtm.start': new Date().getTime(),
#                     event:'gtm.js'
#                 }
#             );
#             var f = d.getElementsByTagName(s)[0],
#                 j = d.createElement(s),
#                 dl = l != 'dataLayer'
#                     ? '&l=' + l
#                     : '';
#             j.async = true;
#             j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#             f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-WDM8865');
#     </script>
# </link></link></link></link></meta></meta></meta></link></link></link></meta></head>
# <body class="customer jm-nigeria min-h-full">
# <input id="authenticated" type="hidden" value="false"/>
# <input id="userRole" type="hidden" value="guest"/>
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WDM8865" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <div class="absolute flex justify-center sm:top-0 w-full z-1000" x-data="notificationHandler()" x-init="init()">
# <div class="flex w-full sm:w-fit flex-col gap-y-2 bottom-0 sm:bottom-[unset] sm:my-3 fixed sm:top-[60px] sm:px-3" x-cloak="" x-show="show">
# <div @mouseenter="pauseHide" @mouseleave="resumeHide" class="flex sm:rounded-lg px-4 py-3 gap-x-3 bg-[#389660] w-full sm:w-fit transition-opacity duration-500 sm:max-w-[556px] gap-y-2 flex-wrap" x-bind:class="{
#                 'bg-[#389660]': type === 'success',
#                 'bg-[#D42B3D]': type === 'error',
#                 'bg-brand-secondary-600': type === 'info' || type === 'warning',
#                 }" x-transition:leave.duration.500ms="">
# <div class="gap-x-4 w-full flex justify-between items-center">
# <div class="flex gap-x-4 items-center">
# <svg fill="none" height="24" viewbox="0 0 24 24" width="24" x-cloak="" x-show="type === 'success'" xmlns="http://www.w3.org/2000/svg">
# <path d="M8.66667 12L10.8889 14.2222L15.3333 9.77778M22 12C22 17.5228 17.5228 22 12 22C6.47715 22 2 17.5228 2 12C2 6.47715 6.47715 2 12 2C17.5228 2 22 6.47715 22 12Z" stroke="white" stroke-linecap="round" stroke-linejoin="round" stroke-width="3"></path>
# </svg>
# <svg fill="none" height="24" viewbox="0 0 24 24" width="24" x-cloak="" x-show="type === 'error'" xmlns="http://www.w3.org/2000/svg">
# <path d="M12 7.55556V12M12 16.4444H12.0111M22 12C22 17.5228 17.5228 22 12 22C6.47715 22 2 17.5228 2 12C2 6.47715 6.47715 2 12 2C17.5228 2 22 6.47715 22 12Z" stroke="white" stroke-linecap="round" stroke-linejoin="round" stroke-width="3"></path>
# </svg>
# <svg fill="none" height="24" viewbox="0 0 24 24" width="24" x-cloak="" x-show="['error', 'success'].indexOf(type) === -1" xmlns="http://www.w3.org/2000/svg">
# <path d="M12 7.55556V12M12 16.4444H12.0111M22 12C22 17.5228 17.5228 22 12 22C6.47715 22 2 17.5228 2 12C2 6.47715 6.47715 2 12 2C17.5228 2 22 6.47715 22 12Z" stroke="white" stroke-linecap="round" stroke-linejoin="round" stroke-width="3"></path>
# </svg>
# <p class="text-sm leading-5 font-normal text-white flex-inline" x-html="message"></p>
# </div>
# <div @click="hideNotification">
# <svg aria-hidden="true" class="cursor-pointer" fill="none" height="18" role="presentation" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M4.29289 4.29289C4.68342 3.90237 5.31658 3.90237 5.70711 4.29289L10 8.58579L14.2929 4.29289C14.6834 3.90237 15.3166 3.90237 15.7071 4.29289C16.0976 4.68342 16.0976 5.31658 15.7071 5.70711L11.4142 10L15.7071 14.2929C16.0976 14.6834 16.0976 15.3166 15.7071 15.7071C15.3166 16.0976 14.6834 16.0976 14.2929 15.7071L10 11.4142L5.70711 15.7071C5.31658 16.0976 4.68342 16.0976 4.29289 15.7071C3.90237 15.3166 3.90237 14.6834 4.29289 14.2929L8.58579 10L4.29289 5.70711C3.90237 5.31658 3.90237 4.68342 4.29289 4.29289Z" fill="white" fill-rule="evenodd"></path>
# </svg> </div>
# </div>
# </div>
# </div>
# </div>
# <script>
#     function notificationHandler() {
#         return {
#             show: false,
#             message: '',
#             type: 'info',
#
#             init() {
#                 window.addEventListener('newNotification', (event) => {
#                     this.showNotification(event.detail.message, event.detail.type);
#                 });
#             },
#
#             showNotification(message, type) {
#                 this.message = message;
#                 this.type = type;
#                 this.show = true;
#                 // Hide the notification after a certain time, say 5 seconds
#                 setTimeout(() => {
#                     this.show = false;
#                 }, (this.message.length / 5) * 1000);
#             },
#
#             pauseHide() {
#                 clearTimeout(this.timeout);
#             },
#
#             resumeHide() {
#                 this.timeout = setTimeout(() => this.show = false, 5000);
#             },
#
#             hideNotification() {
#                 this.show = false;
#             }
#         }
#     }
# </script>
# <header class="flex relative sticky top-0 z-40 flex-col mx-auto w-full bg-white" x-data="{ open: false }">
# <div class="flex z-40 px-4 w-full bg-white shadow lg:px-8">
# <div class="flex flex-col w-full h-16 bg-white lg:items-center lg:justify-between lg:flex-row">
# <div class="flex flex-row justify-between items-center w-full h-full whitespace-nowrap lg:justify-start">
# <a class="flex items-center h-full" href="https://www.jobberman.com">
# <img alt="Jobberman" class="mr-10" loading="lazy" src="https://www.jobberman.com/static-assets/img/ng/landscape.svg" width="180"/>
# </a>
# <div class="flex flex-row justify-between items-center h-full">
# <div class="hidden z-50 lg:flex mx-2 lg:mx-3 xl:mx-6 items-center hover:border-b-2 hover:border-brand-primary hover:-mb-0.5 h-full">
# <div class="relative dropdown-parent">
# <button class="flex flex-row items-center py-2 mt-2 w-full text-sm text-gray-500 whitespace-nowrap md:w-auto md:inline md:mt-0 focus:text-brand-primary hover:text-brand-primary" data-cy="Job Seekers">
# <a href="https://www.jobberman.com/job-seeker">
# Job Seekers
# </a>
# <svg class="inline mt-1 ml-1 w-4 h-4 transition-transform duration-200 transform dropdown-indicator md:-mt-1" fill="currentColor" viewbox="0 0 20 20">
# <path clip-rule="evenodd" d="M5.293 7.293a1 1 0 011.414 0L10 10.586l3.293-3.293a1 1 0 111.414 1.414l-4 4a1 1 0 01-1.414 0l-4-4a1 1 0 010-1.414z" fill-rule="evenodd"></path>
# </svg>
# </button>
# <div class="absolute lg:pt-4 w-full rounded-md dropdown-child md:w-64 z-40">
# <div class="bg-white rounded-md" style="box-shadow: 0 10px 15px -3px rgba(0, 0, 0, 0.1), 0 4px 6px -2px rgba(0, 0, 0, 0.05), 0 0 0 1px rgba(0, 0, 0, 0.05); z-index: 999;">
# <a class="block px-4 py-2 mt-2 text-sm text-gray-500 rounded-t-md rounded-b-md lg:mt-0 hover:text-brand-primary hover:bg-tri-hover focus:text-brand-primary first:rounded-b-none last:rounded-md" href="https://www.jobberman.com/jobs">
# Job Vacancies
# </a>
# <a class="block px-4 py-2 mt-2 text-sm text-gray-500 border-t border-gray-300 border-1 lg:mt-0 hover:text-brand-primary hover:bg-tri-hover focus:text-brand-primary last:rounded-t-none last:rounded-md" href="https://www.jobberman.com/account/cv-services">
# CV Review Services
# </a>
# <a class="block px-4 py-2 mt-2 text-sm text-gray-500 border-t border-gray-300 border-1 lg:mt-0 hover:text-brand-primary hover:bg-tri-hover focus:text-brand-primary last:rounded-t-none last:rounded-md" href="https://www.jobberman.com/softskills">
# Soft Skills Training
# </a>
# <a class="block px-4 py-2 mt-2 text-sm text-gray-500 border-t border-gray-300 border-1 lg:mt-0 hover:text-brand-primary hover:bg-tri-hover focus:text-brand-primary last:rounded-t-none last:rounded-md" href="/discover/job-search-advice">
# Job Search Advice
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="hidden z-50 lg:flex mx-2 lg:mx-3 xl:mx-6 items-center hover:border-b-2 hover:border-brand-primary hover:-mb-0.5 h-full">
# <div class="relative dropdown-parent">
# <button class="flex flex-row items-center py-2 mt-2 w-full text-sm text-gray-500 whitespace-nowrap md:w-auto md:inline md:mt-0 focus:text-brand-primary hover:text-brand-primary" data-cy="Career">
# <a href="/discover">
# Career
# </a>
# <svg class="inline mt-1 ml-1 w-4 h-4 transition-transform duration-200 transform dropdown-indicator md:-mt-1" fill="currentColor" viewbox="0 0 20 20">
# <path clip-rule="evenodd" d="M5.293 7.293a1 1 0 011.414 0L10 10.586l3.293-3.293a1 1 0 111.414 1.414l-4 4a1 1 0 01-1.414 0l-4-4a1 1 0 010-1.414z" fill-rule="evenodd"></path>
# </svg>
# </button>
# <div class="absolute lg:pt-4 w-full rounded-md dropdown-child md:w-64 z-40">
# <div class="bg-white rounded-md" style="box-shadow: 0 10px 15px -3px rgba(0, 0, 0, 0.1), 0 4px 6px -2px rgba(0, 0, 0, 0.05), 0 0 0 1px rgba(0, 0, 0, 0.05); z-index: 999;">
# <a class="block px-4 py-2 mt-2 text-sm text-gray-500 rounded-t-md rounded-b-md lg:mt-0 hover:text-brand-primary hover:bg-tri-hover focus:text-brand-primary" href="/discover/career-development">
# Career Development
# </a>
# <a class="block px-4 py-2 mt-2 text-sm text-gray-500 border-t border-b border-gray-300 border-1 lg:mt-0 hover:text-brand-primary hover:bg-tri-hover focus:text-brand-primary" href="/discover/life-at-work">
# Life at Work
# </a>
# <a class="block px-4 py-2 mt-2 text-sm text-gray-500 rounded-b-md lg:mt-0 hover:text-brand-primary hover:bg-tri-hover focus:text-brand-primary" href="/discover/job-market-news">
# Job Market News
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="hidden z-50 lg:flex mx-2 lg:mx-3 xl:mx-6 items-center hover:border-b-2 hover:border-brand-primary hover:-mb-0.5 h-full">
# <div class="relative dropdown-parent">
# <button class="flex flex-row items-center py-2 mt-2 w-full text-sm text-gray-500 whitespace-nowrap md:w-auto md:inline md:mt-0 focus:text-brand-primary hover:text-brand-primary" data-cy="Employers">
# <a href="https://www.jobberman.com/employer">
# Employers
# </a>
# <svg class="inline mt-1 ml-1 w-4 h-4 transition-transform duration-200 transform dropdown-indicator md:-mt-1" fill="currentColor" viewbox="0 0 20 20">
# <path clip-rule="evenodd" d="M5.293 7.293a1 1 0 011.414 0L10 10.586l3.293-3.293a1 1 0 111.414 1.414l-4 4a1 1 0 01-1.414 0l-4-4a1 1 0 010-1.414z" fill-rule="evenodd"></path>
# </svg>
# </button>
# <div class="absolute lg:pt-4 w-full rounded-md dropdown-child md:w-64 z-40">
# <div class="bg-white rounded-md" style="box-shadow: 0 10px 15px -3px rgba(0, 0, 0, 0.1), 0 4px 6px -2px rgba(0, 0, 0, 0.05), 0 0 0 1px rgba(0, 0, 0, 0.05); z-index: 999;">
# <a class="block px-4 py-2 mt-2 text-sm text-gray-500 lg:mt-0 hover:text-brand-primary hover:bg-tri-hover focus:text-brand-primary first:rounded-t-md last:rounded-b-md" href="https://www.jobberman.com/employer/skills-assessments">
# Skills Assessments
# </a>
# <a class="block px-4 py-2 mt-2 text-sm text-gray-500 border-gray-300 border-1 lg:mt-0 hover:text-brand-primary hover:bg-tri-hover focus:text-brand-primary first:rounded-t-md last:rounded-b-md" href="/discover/employers">
# Employers Corner
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="hidden z-50 lg:flex mx-2 lg:mx-3 xl:mx-6 items-center hover:border-b-2 hover:border-brand-primary hover:-mb-0.5 h-full">
# <div class="relative dropdown-parent">
# <button class="flex flex-row items-center py-2 mt-2 w-full text-sm text-gray-500 whitespace-nowrap md:w-auto md:inline md:mt-0 focus:text-brand-primary hover:text-brand-primary" data-cy="Help Center">
# <a href="https://help-center.jobberman.com/portal/en/home">
# Help Center
# </a>
# <svg class="inline mt-1 ml-1 w-4 h-4 transition-transform duration-200 transform dropdown-indicator md:-mt-1" fill="currentColor" viewbox="0 0 20 20">
# <path clip-rule="evenodd" d="M5.293 7.293a1 1 0 011.414 0L10 10.586l3.293-3.293a1 1 0 111.414 1.414l-4 4a1 1 0 01-1.414 0l-4-4a1 1 0 010-1.414z" fill-rule="evenodd"></path>
# </svg>
# </button>
# <div class="absolute lg:pt-4 w-full rounded-md dropdown-child md:w-64 z-40">
# <div class="bg-white rounded-md" style="box-shadow: 0 10px 15px -3px rgba(0, 0, 0, 0.1), 0 4px 6px -2px rgba(0, 0, 0, 0.05), 0 0 0 1px rgba(0, 0, 0, 0.05); z-index: 999;">
# <a class="block px-4 py-2 mt-2 text-sm text-gray-500 rounded-t-md rounded-b-md lg:mt-0 hover:text-brand-primary hover:bg-tri-hover focus:text-brand-primary first:rounded-b-none last:rounded-b-md" href="https://www.jobberman.com/about#faq">
# Frequently Asked Questions
# </a>
# <a class="block px-4 py-2 mt-2 text-sm text-gray-500 rounded-b-md lg:mt-0 hover:text-brand-primary hover:bg-tri-hover focus:text-brand-primary first:rounded-b-none last:rounded-b-md" href="https://www.jobberman.com/about#contact">
# Contact Us
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="hidden flex-row justify-end items-center w-1/2 lg:flex lg:h-full">
# <a class="flex items-center mx-3 text-sm text-gray-500 cursor-pointer lg:mx-4 hover:text-brand-primary focus:text-brand-primary" data-cy="login-button-navbar" href="https://www.jobberman.com/account/login">
# Log In
# </a>
# <span class="h-3 border-r border-gray-300 border-1"></span>
# <a class="flex items-center mx-3 text-sm text-gray-500 cursor-pointer lg:mx-4 hover:text-brand-primary focus:text-brand-primary" data-cy="sign-up-button-navbar" href="https://www.jobberman.com/account/sign-up">
# Sign Up
# </a>
# <a class="flex items-center justify-center appearance-none font-medium text-center rounded-md text-base py-3 lg:py-2 px-6 bg-pri-default text-white focus:shadow-pri hover:bg-pri-hover flex" href="https://www.jobberman.com/account/employer/jobs/create">
# Post A Job
# </a>
# </div>
# </div>
# <button @click="open = !open" class="ml-auto rounded-md lg:hidden focus:outline-none focus:shadow-outline">
# <svg class="w-6 h-6" fill="currentColor" viewbox="0 0 20 20" x-show="!open">
# <path clip-rule="evenodd" d="M3 5a1 1 0 011-1h12a1 1 0 110 2H4a1 1 0 01-1-1zM3 10a1 1 0 011-1h12a1 1 0 110 2H4a1 1 0 01-1-1zM9 15a1 1 0 011-1h6a1 1 0 110 2h-6a1 1 0 01-1-1z" fill-rule="evenodd"></path>
# </svg>
# <svg class="w-6 h-6" fill="currentColor" viewbox="0 0 20 20" x-show="open">
# <path clip-rule="evenodd" d="M4.293 4.293a1 1 0 011.414 0L10 8.586l4.293-4.293a1 1 0 111.414 1.414L11.414 10l4.293 4.293a1 1 0 01-1.414 1.414L10 11.414l-4.293 4.293a1 1 0 01-1.414-1.414L8.586 10 4.293 5.707a1 1 0 010-1.414z" fill-rule="evenodd"></path>
# </svg>
# </button>
# </div>
# <nav :class="{'flex': open, 'hidden': !open}" class="flex overflow-y-scroll absolute right-0 left-0 flex-col px-4 pt-20 w-full h-screen bg-white lg:hidden" x-cloak="" x-show="open" x-transition:enter="transition ease-out duration-150 transform" x-transition:enter-end="opacity-100 translate-y-0" x-transition:enter-start="opacity-0 -translate-y-5" x-transition:leave="transition ease-in duration-150 transform" x-transition:leave-end="opacity-0 -translate-y-5" x-transition:leave-start="opacity-100 translate-y-0">
# <div class="flex flex-col justify-between">
# <div class="flex flex-row justify-between">
# <a class="flex items-center justify-center appearance-none font-medium text-center rounded-md text-base py-3 lg:py-2 px-6 bg-pri-default text-white focus:shadow-pri hover:bg-pri-hover mr-1 w-full text-center" href="https://www.jobberman.com/account/login">
# Log In
# </a>
# <a class="flex items-center justify-center appearance-none font-medium text-center rounded-md text-base py-3 lg:py-2 px-6 bg-white border border-pri-default text-pri-default focus:shadow-sec hover:bg-sec-hover ml-1 w-full text-center" href="https://www.jobberman.com/account/sign-up">
# Sign Up
# </a>
# </div>
# <div class="flex flex-col py-5 space-y-5">
# <span class="flex flex-row items-center">
# <svg aria-hidden="true" class="mr-2" fill="#000000" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M14.06 9.02l.92.92L5.92 19H5v-.92l9.06-9.06M17.66 3c-.25 0-.51.1-.7.29l-1.83 1.83 3.75 3.75 1.83-1.83c.39-.39.39-1.02 0-1.41l-2.34-2.34c-.2-.2-.45-.29-.71-.29zm-3.6 3.19L3 17.25V21h3.75L17.81 9.94l-3.75-3.75z"></path></svg> <a class="text-base font-medium text-gray-500" href="https://www.jobberman.com/account/employer/jobs/create">
# Post A Job
# </a>
# </span>
# <span class="flex flex-row items-center">
# <svg aria-hidden="true" class="mr-2" fill="currentColor" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M15.5 14h-.79l-.28-.27C15.41 12.59 16 11.11 16 9.5 16 5.91 13.09 3 9.5 3S3 5.91 3 9.5 5.91 16 9.5 16c1.61 0 3.09-.59 4.23-1.57l.27.28v.79l5 4.99L20.49 19l-4.99-5zm-6 0C7.01 14 5 11.99 5 9.5S7.01 5 9.5 5 14 7.01 14 9.5 11.99 14 9.5 14z"></path></svg> <a class="text-base font-medium text-gray-500" href="https://www.jobberman.com/jobs">
# Find a Job
# </a>
# </span>
# </div>
# <div class="flex flex-col">
# <div class="pb-4">
# <div class="py-2">
# <a class="py-2 text-base font-medium text-link-500" href="https://www.jobberman.com/job-seeker">
# Job Seekers
# </a>
# </div>
# <div class="flex flex-col pl-3 space-y-4 border-l-4 border-gray-300">
# <a class="text-gray-500" href="https://www.jobberman.com/jobs">
# Job Vacancies
# </a>
# <a class="text-gray-500" href="https://www.jobberman.com/account/cv-services">
# CV Review Services
# </a>
# <a class="text-gray-500" href="https://www.jobberman.com/softskills">
# Soft Skills Training
# </a>
# <a class="text-gray-500" href="/discover/job-search-advice">
# Job Search Advice
# </a>
# </div>
# </div>
# <div class="pb-4">
# <div class="py-2">
# <a class="py-2 text-base font-medium text-link-500" href="/discover">
# Career
# </a>
# </div>
# <div class="flex flex-col pl-3 space-y-4 border-l-4 border-gray-300">
# <a class="text-gray-500" href="/discover/career-development">
# Career Development
# </a>
# <a class="text-gray-500" href="/discover/life-at-work">
# Life at Work
# </a>
# <a class="text-gray-500" href="/discover/job-market-news">
# Job Market News
# </a>
# </div>
# </div>
# <div class="pb-4">
# <div class="py-2">
# <a class="text-base font-medium text-link-500" href="https://www.jobberman.com/employer">
# Employers
# </a>
# </div>
# <div class="flex flex-col pl-3 space-y-4 border-l-4 border-gray-300">
# <a class="text-gray-500" href="https://www.jobberman.com/employer/skills-assessments">
# Skills Assessments
# </a>
# <a class="text-gray-500" href="/discover/employers">
# Employers Corner
# </a>
# </div>
# </div>
# <div class="pb-4">
# <div class="py-2">
# <a class="text-base font-medium text-link-500" href="https://help-center.jobberman.com/portal/en/home">
# Help Center
# </a>
# </div>
# <div class="flex flex-col pl-3 space-y-4 border-l-4 border-gray-300">
# <a class="text-gray-500" href="https://www.jobberman.com/about#faq">
# Frequently Asked Questions
# </a>
# <a class="text-gray-500" href="https://www.jobberman.com/about#contact">
# Contact Us
# </a>
# </div>
# </div>
# </div>
# </div>
# </nav>
# </header>
# <main class="min-h-screen main-content" style="" x-bind:class="{
#         'lg:ml-[300px]': Boolean() &amp;&amp; $store.global.isSideMenuOpen,
#         'lg:ml-[80px]': Boolean() &amp;&amp; !$store.global.isSideMenuOpen
#     }" x-data="" x-init="$nextTick(() =&gt; $el.style.removeProperty('margin-left'))">
# <section class="min-h-screen main-content bg-veryLight">
# <noscript>
# <aside class="notifications-group">
# </aside>
# </noscript>
# <script>
#     window.notificationMessages = [];
# </script>
# <div :class="{ '-translate-y-[70px] shadow-none' : !showFilter }" class="hidden sticky z-20 w-full bg-gray-100 shadow transition duration-300 md:block no-plain-mode" style="top: 64px;" x-data="{ pageYOffset: 0, showFilter: true }" x-on:scroll.window="() =&gt; {
#                     const diff = pageYOffset - window.pageYOffset;
#                     if (Math.abs(diff) &gt;= 5) {
#                         pageYOffset = window.pageYOffset;
#                         showFilter = diff &gt; 0;
#                     }
#                 }">
# <div class="container my-0 min-h-[70px] flex items-center">
# <form accept-charset="UTF-8" action="https://www.jobberman.com/jobs" class="search_form flex flex-col items-center md:flex-row w-full" method="GET" x-data="TopSearch" x-on:submit="handleSubmit">
# <div class="mr-4 text-gray-700 whitespace-nowrap">
# Find a Job
# </div>
# <select aria-label="Select a job function" class="w-full h-10 pl-2 text-gray-500 rounded-md border border-gray-300 hover:border-gray-400 focus:border-gray-400 placeholder-gray-400 focus:placeholder-gray-900 mb-3 w-full md:mb-0 md:mr-3" name="job_function[]" style="">
# <option value="">All Job Functions</option>
# <option value="accounting-auditing-finance">Accounting, Auditing &amp; Finance</option>
# <option value="admin-office">Admin &amp; Office</option>
# <option value="building-architecture">Building &amp; Architecture</option>
# <option value="community-social-services">Community &amp; Social Services</option>
# <option value="consulting-strategy">Consulting &amp; Strategy</option>
# <option value="creative-design">Creative &amp; Design</option>
# <option value="customer-service-support">Customer Service &amp; Support</option>
# <option value="driver-transport-services">Driver &amp; Transport Services</option>
# <option value="engineering-technology">Engineering &amp; Technology</option>
# <option value="estate-agent-property-management">Estate Agents &amp; Property Management</option>
# <option value="farming-agriculture">Farming &amp; Agriculture</option>
# <option value="food-services-catering">Food Services &amp; Catering</option>
# <option value="health-safety">Health &amp; Safety</option>
# <option value="hospitality-leisure">Hospitality &amp; Leisure</option>
# <option value="human-resources">Human Resources</option>
# <option value="legal-services">Legal Services</option>
# <option value="management-business-development">Management &amp; Business Development</option>
# <option value="marketing-communications">Marketing &amp; Communications</option>
# <option value="medical-pharmaceutical">Medical &amp; Pharmaceutical</option>
# <option value="product-project-management">Product &amp; Project Management</option>
# <option value="quality-control-assurance">Quality Control &amp; Assurance </option>
# <option value="research-teaching-training">Research, Teaching &amp; Training</option>
# <option value="sales">Sales</option>
# <option selected="" value="software-data">Software &amp; Data</option>
# <option value="supply-chain-procurement">Supply Chain &amp; Procurement</option>
# <option value="trades-services">Trades &amp; Services</option>
# </select>
# <select aria-label="Select an industry" class="w-full h-10 pl-2 text-gray-500 rounded-md border border-gray-300 hover:border-gray-400 focus:border-gray-400 placeholder-gray-400 focus:placeholder-gray-900 mb-3 w-full md:mb-0 md:mr-3" name="industry" style="">
# <option value="">All Industries</option>
# <option value="advertising-media-communications">Advertising, Media &amp; Communications</option>
# <option value="agriculture-fishing-forestry">Agriculture, Fishing &amp; Forestry</option>
# <option value="automotive-aviation">Automotive &amp; Aviation</option>
# <option value="banking-finance-insurance">Banking, Finance &amp; Insurance</option>
# <option value="construction">Construction</option>
# <option value="education">Education</option>
# <option value="energy-utilities">Energy &amp; Utilities</option>
# <option value="enforcement-security">Enforcement &amp; Security</option>
# <option value="entertainment-events-sport">Entertainment, Events &amp; Sport</option>
# <option value="government">Government</option>
# <option value="healthcare">Healthcare</option>
# <option value="hospitality-hotel">Hospitality &amp; Hotel</option>
# <option value="it-telecoms">IT &amp; Telecoms</option>
# <option value="law-compliance">Law &amp; Compliance</option>
# <option value="manufacturing-warehousing">Manufacturing &amp; Warehousing</option>
# <option value="mining-energy-metals">Mining, Energy &amp; Metals</option>
# <option value="ngo-npo-charity">NGO, NPO &amp; Charity</option>
# <option value="real-estate">Real Estate</option>
# <option value="recruitment">Recruitment</option>
# <option value="retail-fashion-fmcg">Retail, Fashion &amp; FMCG</option>
# <option value="shipping-logistics">Shipping &amp; Logistics</option>
# <option value="tourism-travel">Tourism &amp; Travel</option>
# <option value="unspecified">Unspecified</option>
# </select>
# <select aria-label="Select a location" class="w-full h-10 pl-2 text-gray-500 rounded-md border border-gray-300 hover:border-gray-400 focus:border-gray-400 placeholder-gray-400 focus:placeholder-gray-900 mb-3 w-full md:mb-0 md:mr-3" name="location" style="">
# <option value="">All Locations</option>
# <option value="abeokuta-ogun">Abeokuta &amp; Ogun State</option>
# <option value="abuja">Abuja</option>
# <option value="enugu">Enugu</option>
# <option value="ibadan-oyo">Ibadan &amp; Oyo State</option>
# <option value="imo">Imo</option>
# <option value="lagos">Lagos</option>
# <option value="maiduguri-borno">Maiduguri &amp; Borno State</option>
# <option value="port-harcourt-rivers">Port Harcourt &amp; Rivers State</option>
# <option value="rest-nigeria">Rest of Nigeria</option>
# <option value="outside-nigeria">Outside Nigeria</option>
# <option value="remote">Remote (Work From Home)</option>
# </select>
# <select aria-label="Select an experience level" class="w-full h-10 pl-2 text-gray-500 rounded-md border border-gray-300 hover:border-gray-400 focus:border-gray-400 placeholder-gray-400 focus:placeholder-gray-900 mb-3 w-full md:mb-0 md:mr-3" name="experience" style="">
# <option value="">All Experience Levels</option>
# <option value="no-experience">No Experience</option>
# <option value="graduate-trainee">Internship &amp; Graduate</option>
# <option value="entry-level">Entry level</option>
# <option value="mid-level">Mid level</option>
# <option value="senior-level">Senior level</option>
# <option value="executive-level">Executive level</option>
# </select>
# <button class="flex items-center justify-center appearance-none font-medium text-center rounded-md text-base py-3 lg:py-2 px-6 bg-pri-default text-white focus:shadow-pri hover:bg-pri-hover w-full lg:w-1/2" type="submit">
# <span class="mr-2" data-cy="search-button-top">Search</span>
# </button>
# </form>
# <script>
#     const TopSearch = {
#         handleSubmit: function(event) {
#             event.preventDefault();
#             event.stopPropagation();
#
#             const form = event.target;
#
#             const getValue = (name) => {
#                 if (form[name]) {
#                     if (form[name].type) {
#                         if (["select-one", "text", "hidden"].indexOf(form[name].type) > -1) {
#                             return form[name].value;
#                         } if (["checkbox", "radio"].indexOf(form[name].type) > -1 && form[name].checked) {
#                             return form[name].value;
#                         }
#                     } else if (form[name].length) {
#                         return form[name].value;
#                     }
#                 }
#
#                 return "";
#             };
#
#             const experienceLevel = getValue("experience[]") || getValue("experience");
#             const jobFunction = getValue("job_function[]") || getValue("job_function");
#             const industry = getValue("industry[]") || getValue("industry");
#             const location = getValue("location[]") || getValue("location");
#             const workType = getValue("work_type");
#             const term = getValue("q");
#             const sortBy = getValue("sort_by");
#
#             // If the logged in user is authenticated
#             // Append authenticated value to make url unique/different to logged out url
#             // same action is happening in SearchFilterViewComposer
#             // line 589 in the multiSearchFilterHref function
#             const authenticated = document.getElementById("authenticated").value;
#             let toUrl = "";
#             if (industry.trim() && jobFunction.trim()) {
#                 const segments = [jobFunction, location, workType].filter((x) => x);
#                 toUrl = `${segments.join("/")}?industry=${industry}`;
#             } else {
#                 const segments = [jobFunction, industry, location, workType].filter((x) => x);
#                 toUrl = segments.join("/");
#             }
#
#             if (experienceLevel) {
#                 toUrl += `${toUrl.indexOf("?") === -1 ? "?" : "&"}experience=${experienceLevel}`;
#             }
#
#             if (term.trim()) {
#                 toUrl += `${toUrl.indexOf("?") === -1 ? "?" : "&"}q=${encodeURI(term.replace(" ", "+"))}`;
#             }
#
#             if (sortBy.trim()) {
#                 toUrl += `${toUrl.indexOf("?") === -1 ? "?" : "&"}sort=${sortBy}`;
#             }
#
#             if (authenticated === "true") {
#                 toUrl += `${toUrl.indexOf("?") === -1 ? "?" : "&"}authenticated=${Date.now()}`;
#             }
#
#             const wholeUrl = `${form.getAttribute("action")}/${toUrl.toLocaleLowerCase()}`;
#             window.location.assign(wholeUrl.replace(/\/$/, ""));
#
#             return false;
#         }
#     };
# </script>
# </div>
# </div>
# <div>
# <div :class="{ '-translate-y-[70px] shadow-none' : !showFilter }" class="sticky z-20 bg-gray-100 shadow transition duration-300 md:hidden" style="top: 60px;" x-data="{ pageYOffset: 0, showFilter: true }" x-on:scroll.window="() =&gt; {
#             const diff = pageYOffset - window.pageYOffset;
#             if (Math.abs(diff) &gt;= 5) {
#                 pageYOffset = window.pageYOffset;
#                 showFilter = diff &gt; 0;
#             }
#         }">
# <div class="block py-3 px-5 w-full search-filter-toggle none-omx-version md:hidden">
# <button class="flex items-center justify-center appearance-none font-medium text-center rounded-md text-base py-3 lg:py-2 px-6 bg-pri-default text-white focus:shadow-pri hover:bg-pri-hover w-full" type="button" x-data="" x-on:click="$store.global.mobileSearchFilterOpen = true">
# Search Filter
# </button>
# </div>
# </div>
# <nav class="w-full mb-5 rounded-md py-3 px-3 lg:px-0 lg:pl-[50px]">
# <ol class="flex flex-wrap text-sm list-reset">
# <li>
# <a class="text-link-400" href="https://www.jobberman.com"><svg aria-hidden="true" class="fill-link-500" fill="#004AB9" height="22" role="presentation" viewbox="0 0 24 24" width="22"><path d="M10 20v-6h4v6h5v-8h3L12 3 2 12h3v8h5z"></path></svg></a>
# </li>
# <li><span class="mx-4 text-gray-500">/</span></li>
# <li>
# <a class="text-link-500" href="/jobs/software-data">Software &amp; Data</a>
# </li>
# </ol>
# </nav>
# <div class="md:flex md:justify-between my-5">
# <div class="w-full md:grow md:mx-[50px]">
# <div class="flex flex-wrap p-5 mb-8 bg-white md:rounded-lg border-y md:border border-gray-300 hover:border-gray-400">
# <h1 class="flex-grow-0 flex-shrink-0 mb-7 text-2xl font-medium text-gray-700 capitalize basis-full">Software &amp; data jobs in Nigeria</h1>
# <div class="flex flex-col flex-grow-0 flex-shrink-0 md:items-center md:flex-row basis-full">
# <div class="text-lg capitalize">
# <span class="pr-2 text-gray-500"><span class="font-medium"><span class="text-brand-secondary pr-2">251</span></span> Jobs Found</span>
# </div>
# <div class="flex mt-4 w-full md:w-auto md:mt-0 md:ml-auto">
# <a class="flex items-center justify-center appearance-none font-medium text-center rounded-md text-base py-3 lg:py-2 px-6 bg-pri-default text-white focus:shadow-pri hover:bg-pri-hover w-full capitalize md:w-auto" href="https://www.jobberman.com/account/customer/alerts/create">
# Create job alert
# </a>
# </div>
# </div>
# </div>
# <div class="mt-5">
# <div class="banner-ad-fixed">
# <div class="banner-ad banner-ad--desktop" data-device-type="desktop" data-google-tag-id="/7108206/Jobberman_Nigeria_dsk_search_atf_h1_728x90 " data-height="90" data-width="728" id="search-desktop-horizontal-1">
# </div>
# <div class="banner-ad banner-ad--mobile" data-device-type="mobile" data-google-tag-id="/7108206/jobberman_nigeria_mob_search_btf_h1_320x50" data-height="50" data-width="320" id="search-mobile-1">
# </div>
# </div>
# </div>
# <div class="mb-5 mx-5 md:mx-0">
# <div class="flex border border-brand-primary bg-brand-primary-50 p-3 gap-y-3 rounded-md flex-col">
# <span class="text-lg leading-6 font-semibold text-gray-900">
# Ready to level up your CV game?
# </span>
# <span class="text-base leading-6 font-medium text-gray-700">
# Collaborate with a professional cv writer to highlight your skills and achievements like never before.
# </span>
# <span class="text-sm leading-5 font-normal text-gray-700">
# Get started now and unlock a world of career possibilities!
# </span>
# <div class="flex justify-end">
# <a class="flex items-center justify-center appearance-none font-medium text-center rounded-md text-sm py-2 px-3 bg-pri-default text-white focus:shadow-pri hover:bg-pri-hover grow lg:grow-0" href="https://www.jobberman.com/account/cv-services">
# Upgrade My CV
# </a>
# </div>
# </div>
# </div>
# <div class="mx-5 md:mx-0 flex flex-wrap col-span-1 mb-5 bg-white rounded-lg border border-gray-300 hover:border-gray-400 focus-within:ring-2 focus-within:ring-offset-2 focus-within:ring-gray-500" data-cy="listing-cards-components">
# <div class="flex flex-grow-0 flex-shrink-0 w-full">
# <div class="flex flex-shrink-0 justify-center items-center w-5 text-xs font-medium text-white uppercase rounded-l-md rounded-bl-none bg-brand-secondary">
# <span class="whitespace-nowrap -rotate-90">FEATURED</span>
# </div>
# <div class="flex-1 flex items-center justify-between px-5 py-3 rounded-tr-md w-full pr-5">
# <div class="w-full">
# <div class="flex items-center">
# <a class="relative mb-3 text-lg font-medium break-words focus:outline-none metrics-apply-now text-link-500 text-loading-animate" href="https://www.jobberman.com/listings/backend-developer-evdg2j" onclick="window.dataLayer &amp;&amp; window.dataLayer.push({
#
#
#                                                     'item_list_name': 'featured listings',
#                             'event': 'select_item',
#                             'listing_type': 'featured'
#
#                         });" title="Backend Developer">
# <span aria-hidden="true" class="absolute inset-0"></span>
# <p class="text-lg font-medium break-words text-link-500">
# Backend Developer
# </p>
# </a>
# </div>
# <p class="text-sm text-link-500">
# <a class="text-loading-animate text-loading-animate-link" href="/company/jobberman-sales-account">
# Jobberman (Third Party Recruitment)
# </a>
# </p>
# <div class="flex flex-wrap mt-3 text-sm text-gray-500 md:py-0">
# <span class="mb-3 px-3 py-1 rounded bg-brand-secondary-100 mr-2 text-loading-hide">
# Remote (Work From Home)
# </span>
# <span class="mb-3 px-3 py-1 rounded bg-brand-secondary-100 mr-2 text-loading-hide">
# Full Time
# </span>
# <span class="mb-3 px-3 py-1 rounded bg-brand-secondary-100 mr-2 text-loading-hide">
# NGN Confidential
# </span>
# </div>
# <p class="text-sm text-gray-500 text-loading-animate inline-block">
# Job Function
# : Software &amp; Data
# </p>
# </div>
# </div>
# </div>
# <div class="flex flex-row items-start items-center px-5 py-3 w-full border-t border-gray-300">
# <span class="md:inline-flex hidden items-center px-3 py-0.5 rounded-full text-xs md:text-sm font-normal bg-green-100 text-green-500 capitalize mr-2">
# New
# <svg class="hidden ml-2 md:inline-flex" fill="none" height="14" viewbox="0 0 14 14" width="14" xmlns="http://www.w3.org/2000/svg">
# <path d="M7 1.75V2.33333M7 11.6667V12.25M12.25 7H11.6667M2.33333 7H1.75M10.7123 10.7123L10.2998 10.2998M3.70017 3.70017L3.28769 3.28769M10.7123 3.28772L10.2999 3.7002M3.7002 10.2999L3.28772 10.7123M9.33333 7C9.33333 8.28866 8.28866 9.33333 7 9.33333C5.71134 9.33333 4.66667 8.28866 4.66667 7C4.66667 5.71134 5.71134 4.66667 7 4.66667C8.28866 4.66667 9.33333 5.71134 9.33333 7Z" stroke="#389660" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.5"></path>
# </svg>
# </span>
# <span class="inline-flex mx-1 items-center p-1.5 capitalize bg-green-100 rounded-full md:hidden w-6 h-6">
# <svg fill="none" height="14" viewbox="0 0 14 14" width="14" xmlns="http://www.w3.org/2000/svg">
# <path d="M7 1.75V2.33333M7 11.6667V12.25M12.25 7H11.6667M2.33333 7H1.75M10.7123 10.7123L10.2998 10.2998M3.70017 3.70017L3.28769 3.28769M10.7123 3.28772L10.2999 3.7002M3.7002 10.2999L3.28772 10.7123M9.33333 7C9.33333 8.28866 8.28866 9.33333 7 9.33333C5.71134 9.33333 4.66667 8.28866 4.66667 7C4.66667 5.71134 5.71134 4.66667 7 4.66667C8.28866 4.66667 9.33333 5.71134 9.33333 7Z" stroke="#389660" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.5"></path>
# </svg>
# </span>
# <p class="ml-auto text-sm font-normal text-gray-700 text-loading-animate">4 days ago</p>
# </div>
# <div class="flex flex-col flex-grow-0 flex-shrink-0 justify-start items-center px-5 py-3 border-t border-gray-300 md:flex-row basis-full">
# <div class="relative bottom-[42px] md:bottom-0">
# <div class="mr-6 flex-shrink-0">
# <a href="/company/jobberman-sales-account">
# <div class="flex justify-center items-center p-1 w-[100px] h-[100px] align-middle bg-white rounded-md border-2 border-gray-300">
# <img alt="Jobberman (Third Party Recruitment)" class="w-full h-full object-contain transition-opacity duration-200 ease-in rounded" height="85" loading="lazy" src="https://i.roamcdn.net/kazi/ng/hq/7ba14d36d8fb4ba479270fceb0feb4b8/-/advertiser-img-ng-jobs-prod/dealer-images/advid3919/adv3919_1629907145.jpg" width="85"/>
# </div>
# </a></div>
# </div>
# <p class="text-sm font-normal text-gray-700 md:text-gray-500 md:pl-5">
# As a full backend developer for websites and apps, your role would involve building and maintaining the server-side components that power both platforms. Here's an overview of your responsibilities:
# </p>
# </div>
# </div>
# <div class="mx-5 md:mx-0 flex flex-wrap col-span-1 mb-5 bg-white rounded-lg border border-gray-300 hover:border-gray-400 focus-within:ring-2 focus-within:ring-offset-2 focus-within:ring-gray-500" data-cy="listing-cards-components">
# <div class="flex flex-grow-0 flex-shrink-0 w-full">
# <div class="flex flex-shrink-0 justify-center items-center w-5 text-xs font-medium text-white uppercase rounded-l-md rounded-bl-none bg-brand-secondary">
# <span class="whitespace-nowrap -rotate-90">FEATURED</span>
# </div>
# <div class="flex-1 flex items-center justify-between px-5 py-3 rounded-tr-md w-full pr-5">
# <div class="w-full">
# <div class="flex items-center">
# <a class="relative mb-3 text-lg font-medium break-words focus:outline-none metrics-apply-now text-link-500 text-loading-animate" href="https://www.jobberman.com/listings/fullstack-web-application-developer-r82g4j" onclick="window.dataLayer &amp;&amp; window.dataLayer.push({
#
#
#                                                     'item_list_name': 'featured listings',
#                             'event': 'select_item',
#                             'listing_type': 'featured'
#
#                         });" title="Fullstack Web Application Developer">
# <span aria-hidden="true" class="absolute inset-0"></span>
# <p class="text-lg font-medium break-words text-link-500">
# Fullstack Web Application Developer
# </p>
# </a>
# </div>
# <p class="text-sm text-link-500">
# <a class="text-loading-animate text-loading-animate-link" href="/company/icst-solutions">
# ICST Solutions
# </a>
# </p>
# <div class="flex flex-wrap mt-3 text-sm text-gray-500 md:py-0">
# <span class="mb-3 px-3 py-1 rounded bg-brand-secondary-100 mr-2 text-loading-hide">
# Lagos
# </span>
# <span class="mb-3 px-3 py-1 rounded bg-brand-secondary-100 mr-2 text-loading-hide">
# Full Time
# </span>
# <span class="mb-3 px-3 py-1 rounded bg-brand-secondary-100 mr-2 text-loading-hide">
# NGN
# <span class="mr-1">
# 250,000 - 400,000
# </span>
# </span>
# </div>
# <p class="text-sm text-gray-500 text-loading-animate inline-block">
# Job Function
# : Software &amp; Data
# </p>
# </div>
# </div>
# </div>
# ...
# <a class="flex justify-between py-4 px-5 w-full border-b border-gray-300" href="https://www.jobberman.com/jobs/software-data">
# <span class="flex items-center m-0 mr-1 w-full text-sm text-left text-gray-700">
# <input class="rounded-full transition text-brand-secondary duration-150 focus:ring-brand-secondary ease-in-out my-1 mr-2 cursor-pointer" name="sort" type="radio" value="latest"/>
# Latest
# </span>
# </a>
# <a class="flex justify-between py-4 px-5 w-full border-b border-gray-300" href="https://www.jobberman.com/jobs/software-data?sort=featured">
# <span class="flex items-center m-0 mr-1 w-full text-sm text-left text-gray-700">
# <input checked="checked" class="rounded-full transition text-brand-secondary duration-150 focus:ring-brand-secondary ease-in-out my-1 mr-2 cursor-pointer" name="sort" type="radio" value="featured"/>
# Featured
# </span>
# </a>
# <a class="flex justify-between py-4 px-5 w-full border-b border-gray-300" href="https://www.jobberman.com/jobs/software-data?sort=popular">
# <span class="flex items-center m-0 mr-1 w-full text-sm text-left text-gray-700">
# <input class="rounded-full transition text-brand-secondary duration-150 focus:ring-brand-secondary ease-in-out my-1 mr-2 cursor-pointer" name="sort" type="radio" value="popular"/>
# Popular
# </span>
# </a>
# </div>
# </div>
# <div class="p-5">
# <a class="flex items-center justify-center appearance-none font-medium text-center rounded-md text-base py-3 lg:py-2 px-6 bg-white border border-pri-default text-pri-default focus:shadow-sec hover:bg-sec-hover block w-full text-center" href="https://www.jobberman.com/jobs">
# Reset Filter
# </a>
# </div>
# </form>
# </div>
# </div>
# <div class="banner-ad banner-ad--desktop" data-device-type="desktop" data-google-tag-id="/7108206/jobberman_nigeria_dsk_search_btf_v1_300x250" data-height="250" data-width="300" id="search-desktop-vertical-1">
# </div>
# <div class="banner-ad banner-ad--desktop" data-device-type="desktop" data-google-tag-id="/7108206/jobberman_nigeria_dsk_search_btf_v2_300x250" data-height="250" data-width="300" id="search-desktop-vertical-2">
# </div>
# </div>
# </div>
# </div>
# </section>
# </main>
# <div class="flex" style="" x-bind:class="{
#             'lg:ml-[300px]': Boolean() &amp;&amp; $store.global.isSideMenuOpen,
#             'lg:ml-[80px]': Boolean() &amp;&amp; !$store.global.isSideMenuOpen
#         }" x-data="" x-init="$nextTick(() =&gt; $el.style.removeProperty('margin-left'))">
# <div class="float-left w-full relative border-[rgba(0,0,0,0.05)] border-t-2">
# <div class="flex flex-col container relative pt-[60px]">
# <div class="flex flex-col flex-wrap justify-between items-center w-full md:flex-row">
# <a class="py-2 text-sm text-link-500" data-cy="about-nav-footer" href="https://www.jobberman.com/about">
# About
# </a>
# <span class="hidden text-gray-300 gray-dash md:block">|</span>
# <a class="py-2 text-sm text-link-500" href="https://www.jobberman.com/companies">
# Companies Hiring
# </a>
# <span class="hidden text-gray-300 gray-dash md:block">|</span>
# <a class="py-2 text-sm text-link-500" href="https://www.jobberman.com/privacy-policy">
# Privacy Policy
# </a>
# <span class="hidden text-gray-300 md:block gray-dash">|</span>
# <a class="py-2 text-sm text-link-500" href="https://www.jobberman.com/terms">
# Terms
# </a>
# <span class="hidden text-gray-300 gray-dash md:block">|</span>
# <a class="py-2 text-sm text-link-500" href="https://www.jobberman.com/account/cv-services">
# CV Review Services
# </a>
# <span class="hidden text-gray-300 gray-dash md:block">|</span>
# <a class="py-2 text-sm text-link-500" href="https://www.jobberman.com/softskills">
# Soft Skills Training
# </a>
# <span class="hidden text-gray-300 gray-dash md:block">|</span>
# <a class="py-2 text-sm text-link-500" href="https://www.jobberman.com/employer/skills-assessments">
# Skills Assessments
# </a>
# <span class="hidden text-gray-300 gray-dash md:block">|</span>
# <a class="py-2 text-sm text-link-500" download="" href="https://static.jobberman.com/banner-rate-card-nigeria.pdf" rel="noopener noreferrer" target="_blank">
# Banner Rate Card
# </a>
# <span class="hidden text-gray-300 gray-dash md:block">|</span>
# </div>
# <div class="flex flex-row justify-center md:justify-start">
# <span class="pt-5 text-sm text-gray-700">
# Follow us On:
# </span>
# </div>
# <div class="flex flex-row justify-center md:justify-start items-center py-5 w-full">
# <a class="mr-4" href="https://www.facebook.com/jobbermannigeria">
# <img alt="Follow us on Facebook" height="32" loading="lazy" src="/build/static-assets/img/icon-facebook.a8ffd853.svg" width="32"/>
# </a>
# <a class="mr-4" href="https://www.instagram.com/jobbermannigeria/">
# <img alt="Follow us on Instagram" height="32" loading="lazy" src="/build/static-assets/img/icon-instagram.f94aacd6.svg" width="32"/>
# </a>
# <a class="mr-4" href="https://www.linkedin.com/company/jobberman">
# <img alt="Follow us on LinkedIn" height="32" loading="lazy" src="/build/static-assets/img/icon-linkedin.26a3db8e.svg" width="32"/>
# </a>
# <a class="mr-4" href="https://www.twitter.com/jobbermandotcom">
# <img alt="Follow us on Twitter" height="32" loading="lazy" src="/build/static-assets/img/icon-twitter.6b47ac5c.svg" width="32"/>
# </a>
# <a class="mr-0 md:mr-4" href="https://www.youtube.com/Jobbermandotcom">
# <img alt="Follow us on YouTube" height="32" loading="lazy" src="/build/static-assets/img/icon-youtube.bd29b086.svg" width="32"/>
# </a>
# <a class="mr-0 md:mr-4" href="https://api.whatsapp.com/send/?phone=2348097202945&amp;text=Hi&amp;type=phone_number&amp;app_absent=0">
# <img alt="Chat with us on Whatsapp" height="32" loading="lazy" src="/build/static-assets/img/icon-whatsapp.611566a5.svg" width="32"/>
# </a>
# <a class="hidden md:block" href="https://play.google.com/store/apps/details?id=com.jobberman&amp;utm_source=jobberman.com&amp;utm_campaign=google-play-badge&amp;pcampaignid=MKT-Other-global-all-co-prtnr-py-2artBadge-Mar2515-1" rel="noopener noreferrer">
# <img alt="Get it on Google Play" height="70" loading="lazy" src="/build/static-assets/img/play-badge.f8a9ba04.png" style="width: 180px;" width="180"/>
# </a>
# </div>
# <a class="block self-center py-5 md:hidden" href="https://play.google.com/store/apps/details?id=com.jobberman&amp;utm_source=jobberman.com&amp;utm_campaign=google-play-badge&amp;pcampaignid=MKT-Other-global-all-co-prtnr-py-2artBadge-Mar2515-1" rel="noopener noreferrer">
# <img alt="Get it on Google Play" height="70" loading="lazy" src="/build/static-assets/img/play-badge.f8a9ba04.png" style="width: 180px;" width="180"/>
# </a>
# <div class="flex flex-row justify-center items-center py-5 w-full border-t-2 border-gray-300">
# <span class="pr-2">
# <svg aria-hidden="true" class="text-gray-500" enable-background="new 0 0 24 24" fill="#9CA3AF" height="18" role="presentation" viewbox="0 0 24 24" width="18" xmlns="http://www.w3.org/2000/svg"><g><rect fill="none" height="24" width="24" x="0"></rect></g><g><g><g><path d="M11.88,9.14c1.28,0.06,1.61,1.15,1.63,1.66h1.79c-0.08-1.98-1.49-3.19-3.45-3.19C9.64,7.61,8,9,8,12.14 c0,1.94,0.93,4.24,3.84,4.24c2.22,0,3.41-1.65,3.44-2.95h-1.79c-0.03,0.59-0.45,1.38-1.63,1.44C10.55,14.83,10,13.81,10,12.14 C10,9.25,11.28,9.16,11.88,9.14z M12,2C6.48,2,2,6.48,2,12s4.48,10,10,10s10-4.48,10-10S17.52,2,12,2z M12,20c-4.41,0-8-3.59-8-8 s3.59-8,8-8s8,3.59,8,8S16.41,20,12,20z"></path></g></g></g></svg> </span>
# <span class="text-base font-medium text-gray-500">
# 2023 Jobberman
# </span>
# </div>
# </div>
# </div>
# </div>
# <script src="https://www.jobberman.com/build/assets/scripts/mini-xhr.umd.min.6cc6f550.js"></script>
# <script async="" src="https://www.jobberman.com/build/assets/scripts/app.1d56e485.js"></script>
# <script>
#     var __gtmDataLayer = [{"event":"view_item_list","ecommerce":{"items":[{"item_name":"Backend Developer","item_id":947420,"index":1,"affiliation":"Jobberman (Third Party Recruitment)","item_brand":"classified listing","item_category":"Software & Data","item_category2":"Banking, Finance & Insurance","item_category3":"Full Time","item_category4":"Mid level","item_list_id":"classified_search_results","item_list_name":"classified search results","item_variant":"salary confidential","location_id":"Remote (Work From Home)","quantity":1},{"item_name":"Fullstack Web Application Developer","item_id":946976,"index":2,"affiliation":"ICST Solutions","item_brand":"classified listing","item_category":"Software & Data","item_category2":"IT & Telecoms","item_category3":"Full Time","item_category4":"Senior level","item_list_id":"classified_search_results","item_list_name":"classified search results","item_variant":"salary publicised","location_id":"Lagos","quantity":1},{"item_name":"Software Engineer (Python\/Django)","item_id":946692,"index":3,"affiliation":"Ayulla Inc.","item_brand":"classified listing","item_category":"Software & Data","item_category2":"IT & Telecoms","item_category3":"Full Time","item_category4":"Mid level","item_list_id":"classified_search_results","item_list_name":"classified search results","item_variant":"salary publicised","location_id":"Remote (Work From Home)","quantity":1},{"item_name":"Website Administrative","item_id":943655,"index":4,"affiliation":"Jobberman (Third Party Recruitment)","item_brand":"classified listing","item_category":"Software & Data","item_category2":"Real Estate","item_category3":"Full Time","item_category4":"Mid level","item_list_id":"classified_search_results","item_list_name":"classified search results","item_variant":"salary confidential","location_id":"Lagos","quantity":1},{"item_name":"Software Engineering Manager (ISW Principal Engineer)","item_id":942802,"index":5,"affiliation":"Jobberman (Third Party Recruitment)","item_brand":"classified listing","item_category":"Software & Data","item_category2":"Banking, Finance & Insurance","item_category3":"Full Time","item_category4":"Executive level","item_list_id":"classified_search_results","item_list_name":"classified search results","item_variant":"salary confidential","location_id":"Lagos","quantity":1},{"item_name":"Web Development Coding Teacher","item_id":942676,"index":6,"affiliation":"Imagine Early years & Elementary","item_brand":"classified listing","item_category":"Software & Data","item_category2":"Education","item_category3":"Part Time","item_category4":"Entry level","item_list_id":"classified_search_results","item_list_name":"classified search results","item_variant":"salary publicised","location_id":"Abuja","quantity":1},{"item_name":"Full Stack Developer","item_id":942674,"index":7,"affiliation":"Imagine Early years & Elementary","item_brand":"classified listing","item_category":"Software & Data","item_category2":"Education","item_category3":"Full Time","item_category4":"Mid level","item_list_id":"classified_search_results","item_list_name":"classified search results","item_variant":"salary publicised","location_id":"Abuja","quantity":1},{"item_name":"Data Collection and Data Entry Specialist","item_id":942630,"index":8,"affiliation":"eConnectTech","item_brand":"classified listing","item_category":"Software & Data","item_category2":"IT & Telecoms","item_category3":"Full Time","item_category4":"Internship & Graduate","item_list_id":"classified_search_results","item_list_name":"classified search results","item_variant":"salary publicised","location_id":"Remote (Work From Home)","quantity":1},{"item_name":"Business Systems Integration Lead","item_id":947967,"index":9,"affiliation":"Collabora","item_brand":"classified listing","item_category":"Software & Data","item_category2":"IT & Telecoms","item_category3":"Full Time","item_category4":"Senior level","item_list_id":"classified_search_results","item_list_name":"classified searc ...
#     if (__gtmDataLayer && !Array.isArray(__gtmDataLayer)) {
#         if (window) {
#             window.dataLayer = window.dataLayer || [];
#             for (var i=0; i<__gtmDataLayer.length; i++) {
#                 window.dataLayer.push(__gtmDataLayer[i]);
#             }
#         }
#     }
# </script>
# <script type="application/ld+json">{
#     "@context": "https://schema.org",
#     "@type": "ItemList",
#     "url": "https://www.jobberman.com/jobs/software-data",
#     "name": "Software & data jobs in Nigeria",
#     "numberOfItems": 16,
#     "itemListElement": [
#         {
#             "@type": "ListItem",
#             "position": 1,
#             "name": "Backend Developer",
#             "url": "https://www.jobberman.com/listings/backend-developer-evdg2j"
#         },
#         {
#             "@type": "ListItem",
#             "position": 2,
#             "name": "Fullstack Web Application Developer",
#             "url": "https://www.jobberman.com/listings/fullstack-web-application-developer-r82g4j"
#         },
#         {
#             "@type": "ListItem",
#             "position": 3,
#             "name": "Software Engineer (Python/Django)",
#             "url": "https://www.jobberman.com/listings/software-engineer-pythondjango-9j0e4w"
#         },
#         {
#             "@type": "ListItem",
#             "position": 4,
#             "name": "Website Administrative",
#             "url": "https://www.jobberman.com/listings/website-administrative-xpdnmq"
#         },
#         {
#             "@type": "ListItem",
#             "position": 5,
#             "name": "Software Engineering Manager (ISW Principal Engineer)",
#             "url": "https://www.jobberman.com/listings/software-engineering-manager-isw-principal-engineer-vwmq2v"
#         },
#         {
#             "@type": "ListItem",
#             "position": 6,
#             "name": "Web Development Coding Teacher",
#             "url": "https://www.jobberman.com/listings/web-development-coding-teacher-r820mg"
#         },
#         {
#             "@type": "ListItem",
#             "position": 7,
#             "name": "Full Stack Developer",
#             "url": "https://www.jobberman.com/listings/full-stack-developer-840dr6"
#         },
#         {
#             "@type": "ListItem",
#             "position": 8,
#             "name": "Data Collection and Data Entry Specialist",
#             "url": "https://www.jobberman.com/listings/remote-data-collection-and-data-entry-specialist-project-waterbury-840dx6"
#         },
#         {
#             "@type": "ListItem",
#             "position": 9,
#             "name": "Business Systems Integration Lead",
#             "url": "https://www.jobberman.com/listings/business-systems-integration-lead-7w8vdg"
#         },
#         {
#             "@type": "ListItem",
#             "position": 10,
#             "name": "Developer - Software Development.Information Technology",
#             "url": "https://www.jobberman.com/listings/developer-software-developmentinformation-technology-84v0g4"
#         },
#         {
#             "@type": "ListItem",
#             "position": 11,
#             "name": "Data Scientist.Enterprise Business NG",
#             "url": "https://www.jobberman.com/listings/data-scientistenterprise-business-ng-zpv2j9"
#         },
#         {
#             "@type": "ListItem",
#             "position": 12,
#             "name": "CTA 2",
#             "url": "https://www.jobberman.com/listings/cta-2-k8rmx2"
#         },
#         {
#             "@type": "ListItem",
#             "position": 13,
#             "name": "Quality Assurance (QA) Engineer",
#             "url": "https://www.jobberman.com/listings/quality-assurance-qa-engineer-gwq548"
#         },
#         {
#             "@type": "ListItem",
#             "position": 14,
#             "name": "Data Science Tutor/Instructor",
#             "url": "https://www.jobberman.com/listings/data-science-tutorinstructor-vw4mdk"
#         },
#         {
#             "@type": "ListItem",
#             "position": 15,
#             "name": "Business Analyst",
#             "url": "https://www.jobberman.com/listings/business-analyst-5d6wpx"
#         },
#         {
#             "@type": "ListItem",
#             "position": 16,
#             "name": "Senior Data Analyst",
#             "url": "https://www.jobberman.com/listings/senior-data-analyst-pmdpgp"
#         }
#     ]
# }</script>
# </body>
# </html>

# %%
#fetch links as list of tag objects
links = soup.find_all("a", attrs={'class':'relative mb-3 text-lg font-medium break-words focus:outline-none metrics-apply-now text-link-500 text-loading-animate'})

# %%
#check if you get proper links
links
# Out:
# [<a class="relative mb-3 text-lg font-medium break-words focus:outline-none metrics-apply-now text-link-500 text-loading-animate" href="https://www.jobberman.com/listings/backend-developer-evdg2j" onclick="window.dataLayer &amp;&amp; window.dataLayer.push({
#
#
#                                                      'item_list_name': 'featured listings',
#                              'event': 'select_item',
#                              'listing_type': 'featured'
#
#                          });" title="Backend Developer">
#  <span aria-hidden="true" class="absolute inset-0"></span>
#  <p class="text-lg font-medium break-words text-link-500">
#  Backend Developer
#  </p>
#  </a>,
#  <a class="relative mb-3 text-lg font-medium break-words focus:outline-none metrics-apply-now text-link-500 text-loading-animate" href="https://www.jobberman.com/listings/fullstack-web-application-developer-r82g4j" onclick="window.dataLayer &amp;&amp; window.dataLayer.push({
#
#
#                                                      'item_list_name': 'featured listings',
#                              'event': 'select_item',
#                              'listing_type': 'featured'
#
#                          });" title="Fullstack Web Application Developer">
#  <span aria-hidden="true" class="absolute inset-0"></span>
#  <p class="text-lg font-medium break-words text-link-500">
#  Fullstack Web Application Developer
#  </p>
#  </a>,
#  <a class="relative mb-3 text-lg font-medium break-words focus:outline-none metrics-apply-now text-link-500 text-loading-animate" href="https://www.jobberman.com/listings/software-engineer-pythondjango-9j0e4w" onclick="window.dataLayer &amp;&amp; window.dataLayer.push({
#
#
#                                                      'item_list_name': 'featured listings',
#                              'event': 'select_item',
#                              'listing_type': 'featured'
#
#                          });" title="Software Engineer (Python/Django)">
#  <span aria-hidden="true" class="absolute inset-0"></span>
#  <p class="text-lg font-medium break-words text-link-500">
#  Software Engineer (Python/Django)
#  </p>
#  </a>,
#  <a class="relative mb-3 text-lg font-medium break-words focus:outline-none metrics-apply-now text-link-500 text-loading-animate" href="https://www.jobberman.com/listings/website-administrative-xpdnmq" onclick="window.dataLayer &amp;&amp; window.dataLayer.push({
#
#
#                                                      'item_list_name': 'featured listings',
#                              'event': 'select_item',
#                              'listing_type': 'featured'
#
#                          });" title="Website Administrative">
#  <span aria-hidden="true" class="absolute inset-0"></span>
#  <p class="text-lg font-medium break-words text-link-500">
#  Website Administrative
#  </p>
#  </a>,
#  <a class="relative mb-3 text-lg font-medium break-words focus:outline-none metrics-apply-now text-link-500 text-loading-animate" href="https://www.jobberman.com/listings/software-engineering-manager-isw-principal-engineer-vwmq2v" onclick="window.dataLayer &amp;&amp; window.dataLayer.push({
#
#
#                                                      'item_list_name': 'featured listings',
#                              'event': 'select_item',
#                              'listing_type': 'featured'
#
#                          });" title="Software Engineering Manager (ISW Principal Engineer)">
#  <span aria-hidden="true" class="absolute inset-0"></span>
#  <p class="text-lg font-medium break-words text-link-500">
#  Software Engineering Manager (ISW Principal Engineer)
#  </p>
#  </a>,
#  <a class="relative mb-3 text-lg font-medium break-words focus:outline-none metrics-apply-now text-link-500 text-loading-animate" href="https://www.jobberman.com/listings/web-development-coding-teacher-r820mg" onclick="window.dataLayer &amp;&amp; window.dataLayer.push({
#
#
#                                                      'item_list_name': 'featured listings',
#                              'event': 'select_item',
#                              'listing_type': 'featured'
#
#                          });" title="Web Development Coding Teacher">
#  <span aria-hidden="true" class="absolute inset-0"></span>
#  <p class="text-lg font-medium break-words text-link-500">
#  Web Development Coding Teacher
#  </p>
#  </a>,
#  <a class="relative mb-3 text-lg font-medium break-words focus:outline-none metrics-apply-now text-link-500 text-loading-animate" href="https://www.jobberman.com/listings/full-stack-developer-840dr6" onclick="window.dataLayer &amp;&amp; window.dataLayer.push({
#
#
#                                                      'item_list_name': 'featured listings',
#                              'event': 'select_item',
#                              'listing_type': 'featured'
#
#                          });" title="Full Stack Developer">
#  <span aria-hidden="true" class="absolute inset-0"></span>
#  <p class="text-lg font-medium break-words text-link-500">
#  Full Stack Developer
#  </p>
#  </a>,
#  <a class="relative mb-3 text-lg font-medium break-words focus:outline-none metrics-apply-now text-link-500 text-loading-animate" href="https://www.jobberman.com/listings/remote-data-collection-and-data-entry-specialist-project-waterbury-840dx6" onclick="window.dataLayer &amp;&amp; window.dataLayer.push({
#
#
#                                                      'item_list_name': 'featured listings',
#                              'event': 'select_item',
#                              'listing_type': 'featured'
#
#                          });" title="Data Collection and Data Entry Specialist">
#  <span aria-hidden="true" class="absolute inset-0"></span>
#  <p class="text-lg font-medium break-words text-link-500">
#  Data Collection and Data Entry Specialist
#  </p>
#  </a>,
#  <a class="relative mb-3 text-lg font-medium break-words focus:outline-none metrics-apply-now text-link-500 text-loading-animate" href="https://www.jobberman.com/listings/business-systems-integration-lead-7w8vdg" onclick="window.dataLayer &amp;&amp; window.dataLayer.push({
#
#
#                                                      'item_list_name': 'classified search results',
#                              'event': 'select_item',
#                              'listing_type': 'normal'
#
#                          });" title="Business Systems Integration Lead">
#  <span aria-hidden="true" class="absolute inset-0"></span>
#  <p class="text-lg font-medium break-words text-link-500">
#  Business Systems Integration Lead
#  </p>
#  </a>,
#  <a class="relative mb-3 text-lg font-medium break-words focus:outline-none metrics-apply-now text-link-500 text-loading-animate" href="https://www.jobberman.com/listings/developer-software-developmentinformation-technology-84v0g4" onclick="window.dataLayer &amp;&amp; window.dataLayer.push({
#
#
#                                                      'item_list_name': 'classified search results',
#                              'event': 'select_item',
#                              'listing_type': 'normal'
#
#                          });" title="Developer - Software Development.Information Technology">
#  <span aria-hidden="true" class="absolute inset-0"></span>
#  <p class="text-lg font-medium break-words text-link-500">
#  Developer - Software Development.Information Technology
#  </p>
#  </a>,
#  <a class="relative mb-3 text-lg font-medium break-words focus:outline-none metrics-apply-now text-link-500 text-loading-animate" href="https://www.jobberman.com/listings/data-scientistenterprise-business-ng-zpv2j9" onclick="window.dataLayer &amp;&amp; window.dataLayer.push({
#
#
#                                                      'item_list_name': 'classified search results',
#                              'event': 'select_item',
#                              'listing_type': 'normal'
#
#                          });" title="Data Scientist.Enterprise Business NG">
#  <span aria-hidden="true" class="absolute inset-0"></span>
#  <p class="text-lg font-medium break-words text-link-500">
#  Data Scientist.Enterprise Business NG
#  </p>
#  </a>,
#  <a class="relative mb-3 text-lg font-medium break-words focus:outline-none metrics-apply-now text-link-500 text-loading-animate" href="https://www.jobberman.com/listings/cta-2-k8rmx2" onclick="window.dataLayer &amp;&amp; window.dataLayer.push({
#
#
#                                                      'item_list_name': 'classified search results',
#                              'event': 'select_item',
#                              'listing_type': 'normal'
#
#                          });" title="CTA 2">
#  <span aria-hidden="true" class="absolute inset-0"></span>
#  <p class="text-lg font-medium break-words text-link-500">
#  CTA 2
#  </p>
#  </a>,
#  <a class="relative mb-3 text-lg font-medium break-words focus:outline-none metrics-apply-now text-link-500 text-loading-animate" href="https://www.jobberman.com/listings/quality-assurance-qa-engineer-gwq548" onclick="window.dataLayer &amp;&amp; window.dataLayer.push({
#
#
#                                                      'item_list_name': 'classified search results',
#                              'event': 'select_item',
#                              'listing_type': 'normal'
#
#                          });" title="Quality Assurance (QA) Engineer">
#  <span aria-hidden="true" class="absolute inset-0"></span>
#  <p class="text-lg font-medium break-words text-link-500">
#  Quality Assurance (QA) Engineer
#  </p>
#  </a>,
#  <a class="relative mb-3 text-lg font-medium break-words focus:outline-none metrics-apply-now text-link-500 text-loading-animate" href="https://www.jobberman.com/listings/data-science-tutorinstructor-vw4mdk" onclick="window.dataLayer &amp;&amp; window.dataLayer.push({
#
#
#                                                      'item_list_name': 'classified search results',
#                              'event': 'select_item',
#                              'listing_type': 'normal'
#
#                          });" title="Data Science Tutor/Instructor">
#  <span aria-hidden="true" class="absolute inset-0"></span>
#  <p class="text-lg font-medium break-words text-link-500">
#  Data Science Tutor/Instructor
#  </p>
#  </a>,
#  <a class="relative mb-3 text-lg font-medium break-words focus:outline-none metrics-apply-now text-link-500 text-loading-animate" href="https://www.jobberman.com/listings/business-analyst-5d6wpx" onclick="window.dataLayer &amp;&amp; window.dataLayer.push({
#
#
#                                                      'item_list_name': 'classified search results',
#                              'event': 'select_item',
#                              'listing_type': 'normal'
#
#                          });" title="Business Analyst">
#  <span aria-hidden="true" class="absolute inset-0"></span>
#  <p class="text-lg font-medium break-words text-link-500">
#  Business Analyst
#  </p>
#  </a>,
#  <a class="relative mb-3 text-lg font-medium break-words focus:outline-none metrics-apply-now text-link-500 text-loading-animate" href="https://www.jobberman.com/listings/senior-data-analyst-pmdpgp" onclick="window.dataLayer &amp;&amp; window.dataLayer.push({
#
#
#                                                      'item_list_name': 'classified search results',
#                              'event': 'select_item',
#                              'listing_type': 'normal'
#
#                          });" title="Senior Data Analyst">
#  <span aria-hidden="true" class="absolute inset-0"></span>
#  <p class="text-lg font-medium break-words text-link-500">
#  Senior Data Analyst
#  </p>
#  </a>]

# %%
# extract the specific link
link = links[0].get('href')

# %%
link
# Out:
# 'https://www.jobberman.com/listings/backend-developer-evdg2j'

# %%
#http request
new_webpage = requests.get(link, headers=HEADERS)

# %%
new_webpage
# Out:
# <Response [200]>

# %%
#soup objects containing all data
new_soup = BeautifulSoup(new_webpage.content, "html.parser")

# %%
new_soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js scroll-smooth" lang="en-ng">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
# <meta content="4hClu3W3PtjepabInbxYOahjMMOlzUNqWBY9OKZJtdA" name="google-site-verification">
# <meta content="4OBlr4vkrswmQYhQhOohC5iEpsPeEPsfo2HUDdA6" name="csrf-token"/>
# <link href="https://user-img-ng-jobs-prod/" rel="dns-prefetch"/>
# <link href="https://advertiser-img-ng-jobs-prod/" rel="dns-prefetch"/>
# <link href="https://www.googletagmanager.com/" rel="dns-prefetch"/>
# <link href="https://www.google-analytics.com/" rel="dns-prefetch"/>
# <link href="https://www.googletagmanager.com/" rel="preconnect"/>
# <link href="https://www.google-analytics.com/" rel="preconnect"/>
# <link href="https://script.hotjar.com/" rel="dns-prefetch"/>
# <link href="https://static.hotjar.com/" rel="dns-prefetch"/>
# <link href="https://vars.hotjar.com/" rel="dns-prefetch"/>
# <link href="https://www.googleadservices.com/" rel="dns-prefetch"/>
# <link href="https://bam.nr-data.com/" rel="dns-prefetch"/>
# <link as="font" crossorigin="anonymous" href="/build/static-assets/fonts/inter-v11-latin-300.c1621953.woff2" rel="preload"/>
# <link as="font" crossorigin="anonymous" href="/build/static-assets/fonts/inter-v11-latin-regular.3a92ec24.woff2" rel="preload"/>
# <link as="font" crossorigin="anonymous" href="/build/static-assets/fonts/inter-v11-latin-500.03a0aa43.woff2" rel="preload"/>
# <link as="font" crossorigin="anonymous" href="/build/static-assets/fonts/inter-v11-latin-700.28198516.woff2" rel="preload"/>
# <link href="https://www.jobberman.com/listings/backend-developer-evdg2j" rel="canonical">
# <meta content="INDEX,FOLLOW" name="robots"/>
# <title>Backend Developer at Jobberman (Third Party Recruitment) | Jobberman</title>
# <meta content="Apply online for the remote backend developer vacancy at Jobberman (Third Party Recruitment) today. Sign up for similar job alerts." name="description">
# <meta content="Backend Developer in Remote (Work From Home)" property="og:title">
# <meta content="Hiring now at Jobberman (Third Party Recruitment)" property="og:description"/>
# <meta content="https://i.roamcdn.net/t/kazi/ng/og-template-1200w-630h/32129ee092eb76f2e2d663cf68ce4f6b/-...%3D/backend-developer-evdg2j.jpg" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="630" property="og:image:height"/>
# <meta content="Find a job" property="og:image:alt"/>
# <meta content="Jobberman" property="og:site_name"/>
# <meta content="Website" property="og:type"/>
# <meta content="2023-11-18T00:00:00+00:00" property="og:updated_time"/>
# <meta content="https://www.jobberman.com/listings/backend-developer-evdg2j" property="og:url"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="Backend Developer in Remote (Work From Home)" name="twitter:title"/>
# <meta content="Hiring now at Jobberman (Third Party Recruitment)" name="twitter:description"/>
# <meta content="https://i.roamcdn.net/t/kazi/ng/og-template-1200w-630h/32129ee092eb76f2e2d663cf68ce4f6b/-...%3D/backend-developer-evdg2j.jpg" name="twitter:image"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="URL_BM_Nigeria" property="banner-targeting-key"/>
# <meta content="" property="banner-targeting-value"/>
# <meta content="f-software-data,remote,mid-level" name="sailthru.tags"/>
# <meta content="189313221529" property="fb:app_id">
# <link href="/build/static-assets/favicon/jobberman/apple-touch-icon.e95ca53c.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/build/static-assets/favicon/jobberman/favicon-32x32.b3c705e3.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/build/static-assets/favicon/jobberman/favicon-16x16.3986e307.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/build/static-assets/favicon/jobberman/manifest.a6626b21.json" rel="manifest"/>
# <link color="#4168C6" href="/build/static-assets/favicon/jobberman/safari-pinned-tab.74493a88.svg" rel="mask-icon"/>
# <link href="/build/static-assets/favicon/jobberman/favicon.3354dcb2.ico" rel="shortcut icon" sizes="any"/>
# <link href="/build/static-assets/favicon/jobberman/favicon.3989c8ed.svg" rel="icon" type="image/svg+xml"/>
# <meta content="#4168C6" name="msapplication-TileColor"/>
# <meta content="/build/static-assets/favicon/jobberman/browserconfig.24e6b14c.xml" name="msapplication-config"/>
# <meta content="/" name="msapplication-starturl"/>
# <meta content="#4168C6" name="theme-color"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <link as="style" href="/build/assets/css/jobberman/fonts.3a1ef93d.css" rel="preload">
# <link href="/build/assets/css/jobberman/fonts.3a1ef93d.css" rel="stylesheet">
# <link as="style" href="/build/assets/css/jobberman/tailwindcss-v3.4cdcd119.css" rel="preload">
# <link href="/build/assets/css/jobberman/tailwindcss-v3.4cdcd119.css" rel="stylesheet">
# <script>
#         document.documentElement.className = document.documentElement.className.replace("no-js", "js");
#
#         if (
#             (
#                 typeof window.operamini !== "undefined"
#                 && window.operamini
#             )
#             || navigator.userAgent.indexOf("Opera Mini/") > -1
#         ) {
#             document.documentElement.className += " opera-mini-mode";
#         }
#     </script>
# <script charset="UTF-8" data-domain-script="42db4c75-a53a-4bda-a784-8baa79be307d" src="https://cdn.cookielaw.org/consent/42db4c75-a53a-4bda-a784-8baa79be307d/otSDKStub.js" type="text/javascript"></script>
# <script type="text/javascript">
#             function OptanonWrapper() { }
#         </script>
# <script>
#         window.dataLayer = window.dataLayer || [];
#         dataLayer = [{"domain_code":"ng","brand":null,"env":"production","route_name":"jobs.show","version":"master-3718","session_hash":"fa86f8ec86cf6c524c62ff8b81778314","timestamp":1700265845,"event":"set_page_data","currency":"NGN","listing_id":947420,"listing_url":"https:\/\/www.jobberman.com\/listings\/backend-developer-evdg2j","listing_title":"Backend Developer","linkout_url":"","trailing_slug":"backend-developer-evdg2j","listing_type":"Featured","category_name":"Software & Data","work_type":"Full Time","experience_level":"Mid level","category_slug":"software-data","content_type":"classified listing","employer_name":"Jobberman (Third Party Recruitment)","location_name":"Remote (Work From Home)","user_registration_status":"","locale":"en_ng","breadcrumb_url":"\/jobs\/software-data?utm_medium=push&utm_source=browser&utm_campaign=return-listing","value":"75000.00","listing_source":"organic","item_list_id":"888afb5abc993cb341712a789b95b5d4"}];
#             </script>
# <script>
#         (function(w,d,s,l,i){
#             w[l] = w[l] || [];
#             w[l].push(
#                 {
#                     'gtm.start': new Date().getTime(),
#                     event:'gtm.js'
#                 }
#             );
#             var f = d.getElementsByTagName(s)[0],
#                 j = d.createElement(s),
#                 dl = l != 'dataLayer'
#                     ? '&l=' + l
#                     : '';
#             j.async = true;
#             j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#             f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-WDM8865');
#     </script>
# </link></link></link></link></meta></meta></meta></link></meta></head>
# <body class="customer jm-nigeria min-h-full">
# <input id="authenticated" type="hidden" value="false"/>
# <input id="userRole" type="hidden" value="guest"/>
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WDM8865" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <div class="absolute flex justify-center sm:top-0 w-full z-1000" x-data="notificationHandler()" x-init="init()">
# <div class="flex w-full sm:w-fit flex-col gap-y-2 bottom-0 sm:bottom-[unset] sm:my-3 fixed sm:top-[60px] sm:px-3" x-cloak="" x-show="show">
# <div @mouseenter="pauseHide" @mouseleave="resumeHide" class="flex sm:rounded-lg px-4 py-3 gap-x-3 bg-[#389660] w-full sm:w-fit transition-opacity duration-500 sm:max-w-[556px] gap-y-2 flex-wrap" x-bind:class="{
#                 'bg-[#389660]': type === 'success',
#                 'bg-[#D42B3D]': type === 'error',
#                 'bg-brand-secondary-600': type === 'info' || type === 'warning',
#                 }" x-transition:leave.duration.500ms="">
# <div class="gap-x-4 w-full flex justify-between items-center">
# <div class="flex gap-x-4 items-center">
# <svg fill="none" height="24" viewbox="0 0 24 24" width="24" x-cloak="" x-show="type === 'success'" xmlns="http://www.w3.org/2000/svg">
# <path d="M8.66667 12L10.8889 14.2222L15.3333 9.77778M22 12C22 17.5228 17.5228 22 12 22C6.47715 22 2 17.5228 2 12C2 6.47715 6.47715 2 12 2C17.5228 2 22 6.47715 22 12Z" stroke="white" stroke-linecap="round" stroke-linejoin="round" stroke-width="3"></path>
# </svg>
# <svg fill="none" height="24" viewbox="0 0 24 24" width="24" x-cloak="" x-show="type === 'error'" xmlns="http://www.w3.org/2000/svg">
# <path d="M12 7.55556V12M12 16.4444H12.0111M22 12C22 17.5228 17.5228 22 12 22C6.47715 22 2 17.5228 2 12C2 6.47715 6.47715 2 12 2C17.5228 2 22 6.47715 22 12Z" stroke="white" stroke-linecap="round" stroke-linejoin="round" stroke-width="3"></path>
# </svg>
# <svg fill="none" height="24" viewbox="0 0 24 24" width="24" x-cloak="" x-show="['error', 'success'].indexOf(type) === -1" xmlns="http://www.w3.org/2000/svg">
# <path d="M12 7.55556V12M12 16.4444H12.0111M22 12C22 17.5228 17.5228 22 12 22C6.47715 22 2 17.5228 2 12C2 6.47715 6.47715 2 12 2C17.5228 2 22 6.47715 22 12Z" stroke="white" stroke-linecap="round" stroke-linejoin="round" stroke-width="3"></path>
# </svg>
# <p class="text-sm leading-5 font-normal text-white flex-inline" x-html="message"></p>
# </div>
# <div @click="hideNotification">
# <svg aria-hidden="true" class="cursor-pointer" fill="none" height="18" role="presentation" viewbox="0 0 20 20" width="18" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M4.29289 4.29289C4.68342 3.90237 5.31658 3.90237 5.70711 4.29289L10 8.58579L14.2929 4.29289C14.6834 3.90237 15.3166 3.90237 15.7071 4.29289C16.0976 4.68342 16.0976 5.31658 15.7071 5.70711L11.4142 10L15.7071 14.2929C16.0976 14.6834 16.0976 15.3166 15.7071 15.7071C15.3166 16.0976 14.6834 16.0976 14.2929 15.7071L10 11.4142L5.70711 15.7071C5.31658 16.0976 4.68342 16.0976 4.29289 15.7071C3.90237 15.3166 3.90237 14.6834 4.29289 14.2929L8.58579 10L4.29289 5.70711C3.90237 5.31658 3.90237 4.68342 4.29289 4.29289Z" fill="white" fill-rule="evenodd"></path>
# </svg> </div>
# </div>
# </div>
# </div>
# </div>
# <script>
#     function notificationHandler() {
#         return {
#             show: false,
#             message: '',
#             type: 'info',
#
#             init() {
#                 window.addEventListener('newNotification', (event) => {
#                     this.showNotification(event.detail.message, event.detail.type);
#                 });
#             },
#
#             showNotification(message, type) {
#                 this.message = message;
#                 this.type = type;
#                 this.show = true;
#                 // Hide the notification after a certain time, say 5 seconds
#                 setTimeout(() => {
#                     this.show = false;
#                 }, (this.message.length / 5) * 1000);
#             },
#
#             pauseHide() {
#                 clearTimeout(this.timeout);
#             },
#
#             resumeHide() {
#                 this.timeout = setTimeout(() => this.show = false, 5000);
#             },
#
#             hideNotification() {
#                 this.show = false;
#             }
#         }
#     }
# </script>
# <header class="flex relative sticky top-0 z-40 flex-col mx-auto w-full bg-white" x-data="{ open: false }">
# <div class="flex z-40 px-4 w-full bg-white shadow lg:px-8">
# <div class="flex flex-col w-full h-16 bg-white lg:items-center lg:justify-between lg:flex-row">
# <div class="flex flex-row justify-between items-center w-full h-full whitespace-nowrap lg:justify-start">
# <a class="flex items-center h-full" href="https://www.jobberman.com">
# <img alt="Jobberman" class="mr-10" loading="lazy" src="https://www.jobberman.com/static-assets/img/ng/landscape.svg" width="180"/>
# </a>
# <div class="flex flex-row justify-between items-center h-full">
# <div class="hidden z-50 lg:flex mx-2 lg:mx-3 xl:mx-6 items-center hover:border-b-2 hover:border-brand-primary hover:-mb-0.5 h-full">
# <div class="relative dropdown-parent">
# <button class="flex flex-row items-center py-2 mt-2 w-full text-sm text-gray-500 whitespace-nowrap md:w-auto md:inline md:mt-0 focus:text-brand-primary hover:text-brand-primary" data-cy="Job Seekers">
# <a href="https://www.jobberman.com/job-seeker">
# Job Seekers
# </a>
# <svg class="inline mt-1 ml-1 w-4 h-4 transition-transform duration-200 transform dropdown-indicator md:-mt-1" fill="currentColor" viewbox="0 0 20 20">
# <path clip-rule="evenodd" d="M5.293 7.293a1 1 0 011.414 0L10 10.586l3.293-3.293a1 1 0 111.414 1.414l-4 4a1 1 0 01-1.414 0l-4-4a1 1 0 010-1.414z" fill-rule="evenodd"></path>
# </svg>
# </button>
# <div class="absolute lg:pt-4 w-full rounded-md dropdown-child md:w-64 z-40">
# <div class="bg-white rounded-md" style="box-shadow: 0 10px 15px -3px rgba(0, 0, 0, 0.1), 0 4px 6px -2px rgba(0, 0, 0, 0.05), 0 0 0 1px rgba(0, 0, 0, 0.05); z-index: 999;">
# <a class="block px-4 py-2 mt-2 text-sm text-gray-500 rounded-t-md rounded-b-md lg:mt-0 hover:text-brand-primary hover:bg-tri-hover focus:text-brand-primary first:rounded-b-none last:rounded-md" href="https://www.jobberman.com/jobs">
# Job Vacancies
# </a>
# <a class="block px-4 py-2 mt-2 text-sm text-gray-500 border-t border-gray-300 border-1 lg:mt-0 hover:text-brand-primary hover:bg-tri-hover focus:text-brand-primary last:rounded-t-none last:rounded-md" href="https://www.jobberman.com/account/cv-services">
# CV Review Services
# </a>
# <a class="block px-4 py-2 mt-2 text-sm text-gray-500 border-t border-gray-300 border-1 lg:mt-0 hover:text-brand-primary hover:bg-tri-hover focus:text-brand-primary last:rounded-t-none last:rounded-md" href="https://www.jobberman.com/softskills">
# Soft Skills Training
# </a>
# <a class="block px-4 py-2 mt-2 text-sm text-gray-500 border-t border-gray-300 border-1 lg:mt-0 hover:text-brand-primary hover:bg-tri-hover focus:text-brand-primary last:rounded-t-none last:rounded-md" href="/discover/job-search-advice">
# Job Search Advice
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="hidden z-50 lg:flex mx-2 lg:mx-3 xl:mx-6 items-center hover:border-b-2 hover:border-brand-primary hover:-mb-0.5 h-full">
# <div class="relative dropdown-parent">
# <button class="flex flex-row items-center py-2 mt-2 w-full text-sm text-gray-500 whitespace-nowrap md:w-auto md:inline md:mt-0 focus:text-brand-primary hover:text-brand-primary" data-cy="Career">
# <a href="/discover">
# Career
# </a>
# <svg class="inline mt-1 ml-1 w-4 h-4 transition-transform duration-200 transform dropdown-indicator md:-mt-1" fill="currentColor" viewbox="0 0 20 20">
# <path clip-rule="evenodd" d="M5.293 7.293a1 1 0 011.414 0L10 10.586l3.293-3.293a1 1 0 111.414 1.414l-4 4a1 1 0 01-1.414 0l-4-4a1 1 0 010-1.414z" fill-rule="evenodd"></path>
# </svg>
# </button>
# <div class="absolute lg:pt-4 w-full rounded-md dropdown-child md:w-64 z-40">
# <div class="bg-white rounded-md" style="box-shadow: 0 10px 15px -3px rgba(0, 0, 0, 0.1), 0 4px 6px -2px rgba(0, 0, 0, 0.05), 0 0 0 1px rgba(0, 0, 0, 0.05); z-index: 999;">
# <a class="block px-4 py-2 mt-2 text-sm text-gray-500 rounded-t-md rounded-b-md lg:mt-0 hover:text-brand-primary hover:bg-tri-hover focus:text-brand-primary" href="/discover/career-development">
# Career Development
# </a>
# <a class="block px-4 py-2 mt-2 text-sm text-gray-500 border-t border-b border-gray-300 border-1 lg:mt-0 hover:text-brand-primary hover:bg-tri-hover focus:text-brand-primary" href="/discover/life-at-work">
# Life at Work
# </a>
# <a class="block px-4 py-2 mt-2 text-sm text-gray-500 rounded-b-md lg:mt-0 hover:text-brand-primary hover:bg-tri-hover focus:text-brand-primary" href="/discover/job-market-news">
# Job Market News
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="hidden z-50 lg:flex mx-2 lg:mx-3 xl:mx-6 items-center hover:border-b-2 hover:border-brand-primary hover:-mb-0.5 h-full">
# <div class="relative dropdown-parent">
# <button class="flex flex-row items-center py-2 mt-2 w-full text-sm text-gray-500 whitespace-nowrap md:w-auto md:inline md:mt-0 focus:text-brand-primary hover:text-brand-primary" data-cy="Employers">
# <a href="https://www.jobberman.com/employer">
# Employers
# </a>
# <svg class="inline mt-1 ml-1 w-4 h-4 transition-transform duration-200 transform dropdown-indicator md:-mt-1" fill="currentColor" viewbox="0 0 20 20">
# <path clip-rule="evenodd" d="M5.293 7.293a1 1 0 011.414 0L10 10.586l3.293-3.293a1 1 0 111.414 1.414l-4 4a1 1 0 01-1.414 0l-4-4a1 1 0 010-1.414z" fill-rule="evenodd"></path>
# </svg>
# </button>
# <div class="absolute lg:pt-4 w-full rounded-md dropdown-child md:w-64 z-40">
# <div class="bg-white rounded-md" style="box-shadow: 0 10px 15px -3px rgba(0, 0, 0, 0.1), 0 4px 6px -2px rgba(0, 0, 0, 0.05), 0 0 0 1px rgba(0, 0, 0, 0.05); z-index: 999;">
# <a class="block px-4 py-2 mt-2 text-sm text-gray-500 lg:mt-0 hover:text-brand-primary hover:bg-tri-hover focus:text-brand-primary first:rounded-t-md last:rounded-b-md" href="https://www.jobberman.com/employer/skills-assessments">
# Skills Assessments
# </a>
# <a class="block px-4 py-2 mt-2 text-sm text-gray-500 border-gray-300 border-1 lg:mt-0 hover:text-brand-primary hover:bg-tri-hover focus:text-brand-primary first:rounded-t-md last:rounded-b-md" href="/discover/employers">
# Employers Corner
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="hidden z-50 lg:flex mx-2 lg:mx-3 xl:mx-6 items-center hover:border-b-2 hover:border-brand-primary hover:-mb-0.5 h-full">
# <div class="relative dropdown-parent">
# <button class="flex flex-row items-center py-2 mt-2 w-full text-sm text-gray-500 whitespace-nowrap md:w-auto md:inline md:mt-0 focus:text-brand-primary hover:text-brand-primary" data-cy="Help Center">
# <a href="https://help-center.jobberman.com/portal/en/home">
# Help Center
# </a>
# <svg class="inline mt-1 ml-1 w-4 h-4 transition-transform duration-200 transform dropdown-indicator md:-mt-1" fill="currentColor" viewbox="0 0 20 20">
# <path clip-rule="evenodd" d="M5.293 7.293a1 1 0 011.414 0L10 10.586l3.293-3.293a1 1 0 111.414 1.414l-4 4a1 1 0 01-1.414 0l-4-4a1 1 0 010-1.414z" fill-rule="evenodd"></path>
# </svg>
# </button>
# <div class="absolute lg:pt-4 w-full rounded-md dropdown-child md:w-64 z-40">
# <div class="bg-white rounded-md" style="box-shadow: 0 10px 15px -3px rgba(0, 0, 0, 0.1), 0 4px 6px -2px rgba(0, 0, 0, 0.05), 0 0 0 1px rgba(0, 0, 0, 0.05); z-index: 999;">
# <a class="block px-4 py-2 mt-2 text-sm text-gray-500 rounded-t-md rounded-b-md lg:mt-0 hover:text-brand-primary hover:bg-tri-hover focus:text-brand-primary first:rounded-b-none last:rounded-b-md" href="https://www.jobberman.com/about#faq">
# Frequently Asked Questions
# </a>
# <a class="block px-4 py-2 mt-2 text-sm text-gray-500 rounded-b-md lg:mt-0 hover:text-brand-primary hover:bg-tri-hover focus:text-brand-primary first:rounded-b-none last:rounded-b-md" href="https://www.jobberman.com/about#contact">
# Contact Us
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="hidden flex-row justify-end items-center w-1/2 lg:flex lg:h-full">
# <a class="flex items-center mx-3 text-sm text-gray-500 cursor-pointer lg:mx-4 hover:text-brand-primary focus:text-brand-primary" data-cy="login-button-navbar" href="https://www.jobberman.com/account/login">
# Log In
# </a>
# <span class="h-3 border-r border-gray-300 border-1"></span>
# <a class="flex items-center mx-3 text-sm text-gray-500 cursor-pointer lg:mx-4 hover:text-brand-primary focus:text-brand-primary" data-cy="sign-up-button-navbar" href="https://www.jobberman.com/account/sign-up">
# Sign Up
# </a>
# <a class="flex items-center justify-center appearance-none font-medium text-center rounded-md text-base py-3 lg:py-2 px-6 bg-pri-default text-white focus:shadow-pri hover:bg-pri-hover flex" href="https://www.jobberman.com/account/employer/jobs/create">
# Post A Job
# </a>
# </div>
# </div>
# <button @click="open = !open" class="ml-auto rounded-md lg:hidden focus:outline-none focus:shadow-outline">
# <svg class="w-6 h-6" fill="currentColor" viewbox="0 0 20 20" x-show="!open">
# <path clip-rule="evenodd" d="M3 5a1 1 0 011-1h12a1 1 0 110 2H4a1 1 0 01-1-1zM3 10a1 1 0 011-1h12a1 1 0 110 2H4a1 1 0 01-1-1zM9 15a1 1 0 011-1h6a1 1 0 110 2h-6a1 1 0 01-1-1z" fill-rule="evenodd"></path>
# </svg>
# <svg class="w-6 h-6" fill="currentColor" viewbox="0 0 20 20" x-show="open">
# <path clip-rule="evenodd" d="M4.293 4.293a1 1 0 011.414 0L10 8.586l4.293-4.293a1 1 0 111.414 1.414L11.414 10l4.293 4.293a1 1 0 01-1.414 1.414L10 11.414l-4.293 4.293a1 1 0 01-1.414-1.414L8.586 10 4.293 5.707a1 1 0 010-1.414z" fill-rule="evenodd"></path>
# </svg>
# </button>
# </div>
# <nav :class="{'flex': open, 'hidden': !open}" class="flex overflow-y-scroll absolute right-0 left-0 flex-col px-4 pt-20 w-full h-screen bg-white lg:hidden" x-cloak="" x-show="open" x-transition:enter="transition ease-out duration-150 transform" x-transition:enter-end="opacity-100 translate-y-0" x-transition:enter-start="opacity-0 -translate-y-5" x-transition:leave="transition ease-in duration-150 transform" x-transition:leave-end="opacity-0 -translate-y-5" x-transition:leave-start="opacity-100 translate-y-0">
# <div class="flex flex-col justify-between">
# <div class="flex flex-row justify-between">
# <a class="flex items-center justify-center appearance-none font-medium text-center rounded-md text-base py-3 lg:py-2 px-6 bg-pri-default text-white focus:shadow-pri hover:bg-pri-hover mr-1 w-full text-center" href="https://www.jobberman.com/account/login">
# Log In
# </a>
# <a class="flex items-center justify-center appearance-none font-medium text-center rounded-md text-base py-3 lg:py-2 px-6 bg-white border border-pri-default text-pri-default focus:shadow-sec hover:bg-sec-hover ml-1 w-full text-center" href="https://www.jobberman.com/account/sign-up">
# Sign Up
# </a>
# </div>
# <div class="flex flex-col py-5 space-y-5">
# <span class="flex flex-row items-center">
# <svg aria-hidden="true" class="mr-2" fill="#000000" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M14.06 9.02l.92.92L5.92 19H5v-.92l9.06-9.06M17.66 3c-.25 0-.51.1-.7.29l-1.83 1.83 3.75 3.75 1.83-1.83c.39-.39.39-1.02 0-1.41l-2.34-2.34c-.2-.2-.45-.29-.71-.29zm-3.6 3.19L3 17.25V21h3.75L17.81 9.94l-3.75-3.75z"></path></svg> <a class="text-base font-medium text-gray-500" href="https://www.jobberman.com/account/employer/jobs/create">
# Post A Job
# </a>
# </span>
# <span class="flex flex-row items-center">
# <svg aria-hidden="true" class="mr-2" fill="currentColor" height="24" role="presentation" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg"><path d="M15.5 14h-.79l-.28-.27C15.41 12.59 16 11.11 16 9.5 16 5.91 13.09 3 9.5 3S3 5.91 3 9.5 5.91 16 9.5 16c1.61 0 3.09-.59 4.23-1.57l.27.28v.79l5 4.99L20.49 19l-4.99-5zm-6 0C7.01 14 5 11.99 5 9.5S7.01 5 9.5 5 14 7.01 14 9.5 11.99 14 9.5 14z"></path></svg> <a class="text-base font-medium text-gray-500" href="https://www.jobberman.com/jobs">
# Find a Job
# </a>
# </span>
# </div>
# <div class="flex flex-col">
# <div class="pb-4">
# <div class="py-2">
# <a class="py-2 text-base font-medium text-link-500" href="https://www.jobberman.com/job-seeker">
# Job Seekers
# </a>
# </div>
# <div class="flex flex-col pl-3 space-y-4 border-l-4 border-gray-300">
# <a class="text-gray-500" href="https://www.jobberman.com/jobs">
# Job Vacancies
# </a>
# <a class="text-gray-500" href="https://www.jobberman.com/account/cv-services">
# CV Review Services
# </a>
# <a class="text-gray-500" href="https://www.jobberman.com/softskills">
# Soft Skills Training
# </a>
# <a class="text-gray-500" href="/discover/job-search-advice">
# Job Search Advice
# </a>
# </div>
# </div>
# <div class="pb-4">
# <div class="py-2">
# <a class="py-2 text-base font-medium text-link-500" href="/discover">
# Career
# </a>
# </div>
# <div class="flex flex-col pl-3 space-y-4 border-l-4 border-gray-300">
# <a class="text-gray-500" href="/discover/career-development">
# Career Development
# </a>
# <a class="text-gray-500" href="/discover/life-at-work">
# Life at Work
# </a>
# <a class="text-gray-500" href="/discover/job-market-news">
# Job Market News
# </a>
# </div>
# </div>
# <div class="pb-4">
# <div class="py-2">
# <a class="text-base font-medium text-link-500" href="https://www.jobberman.com/employer">
# Employers
# </a>
# </div>
# <div class="flex flex-col pl-3 space-y-4 border-l-4 border-gray-300">
# <a class="text-gray-500" href="https://www.jobberman.com/employer/skills-assessments">
# Skills Assessments
# </a>
# <a class="text-gray-500" href="/discover/employers">
# Employers Corner
# </a>
# </div>
# </div>
# <div class="pb-4">
# <div class="py-2">
# <a class="text-base font-medium text-link-500" href="https://help-center.jobberman.com/portal/en/home">
# Help Center
# </a>
# </div>
# <div class="flex flex-col pl-3 space-y-4 border-l-4 border-gray-300">
# <a class="text-gray-500" href="https://www.jobberman.com/about#faq">
# Frequently Asked Questions
# </a>
# <a class="text-gray-500" href="https://www.jobberman.com/about#contact">
# Contact Us
# </a>
# </div>
# </div>
# </div>
# </div>
# </nav>
# </header>
# <main class="min-h-screen main-content" style="" x-bind:class="{
#         'lg:ml-[300px]': Boolean() &amp;&amp; $store.global.isSideMenuOpen,
#         'lg:ml-[80px]': Boolean() &amp;&amp; !$store.global.isSideMenuOpen
#     }" x-data="" x-init="$nextTick(() =&gt; $el.style.removeProperty('margin-left'))">
# <section class="min-h-screen main-content bg-veryLight">
# <noscript>
# <aside class="notifications-group">
# </aside>
# </noscript>
# <script>
#     window.notificationMessages = [];
# </script>
# <div :class="{ '-translate-y-[70px] shadow-none' : !showFilter }" class="hidden sticky z-20 w-full bg-gray-100 shadow transition duration-300 md:block no-plain-mode" style="top: 64px;" x-data="{ pageYOffset: 0, showFilter: true }" x-on:scroll.window="() =&gt; {
#                     const diff = pageYOffset - window.pageYOffset;
#                     if (Math.abs(diff) &gt;= 5) {
#                         pageYOffset = window.pageYOffset;
#                         showFilter = diff &gt; 0;
#                     }
#                 }">
# <div class="container my-0 min-h-[70px] flex items-center">
# <form accept-charset="UTF-8" action="https://www.jobberman.com/jobs" class="search_form flex flex-col items-center md:flex-row w-full" method="GET" x-data="TopSearch" x-on:submit="handleSubmit">
# <div class="mr-4 text-gray-700 whitespace-nowrap">
# Find a Job
# </div>
# <select aria-label="Select a job function" class="w-full h-10 pl-2 text-gray-500 rounded-md border border-gray-300 hover:border-gray-400 focus:border-gray-400 placeholder-gray-400 focus:placeholder-gray-900 mb-3 w-full md:mb-0 md:mr-3" name="job_function[]" style="">
# <option value="">All Job Functions</option>
# <option value="accounting-auditing-finance">Accounting, Auditing &amp; Finance</option>
# <option value="admin-office">Admin &amp; Office</option>
# <option value="building-architecture">Building &amp; Architecture</option>
# <option value="community-social-services">Community &amp; Social Services</option>
# <option value="consulting-strategy">Consulting &amp; Strategy</option>
# <option value="creative-design">Creative &amp; Design</option>
# <option value="customer-service-support">Customer Service &amp; Support</option>
# <option value="driver-transport-services">Driver &amp; Transport Services</option>
# <option value="engineering-technology">Engineering &amp; Technology</option>
# <option value="estate-agent-property-management">Estate Agents &amp; Property Management</option>
# <option value="farming-agriculture">Farming &amp; Agriculture</option>
# <option value="food-services-catering">Food Services &amp; Catering</option>
# <option value="health-safety">Health &amp; Safety</option>
# <option value="hospitality-leisure">Hospitality &amp; Leisure</option>
# <option value="human-resources">Human Resources</option>
# <option value="legal-services">Legal Services</option>
# <option value="management-business-development">Management &amp; Business Development</option>
# <option value="marketing-communications">Marketing &amp; Communications</option>
# <option value="medical-pharmaceutical">Medical &amp; Pharmaceutical</option>
# <option value="product-project-management">Product &amp; Project Management</option>
# <option value="quality-control-assurance">Quality Control &amp; Assurance </option>
# <option value="research-teaching-training">Research, Teaching &amp; Training</option>
# <option value="sales">Sales</option>
# <option value="software-data">Software &amp; Data</option>
# <option value="supply-chain-procurement">Supply Chain &amp; Procurement</option>
# <option value="trades-services">Trades &amp; Services</option>
# </select>
# <select aria-label="Select an industry" class="w-full h-10 pl-2 text-gray-500 rounded-md border border-gray-300 hover:border-gray-400 focus:border-gray-400 placeholder-gray-400 focus:placeholder-gray-900 mb-3 w-full md:mb-0 md:mr-3" name="industry" style="">
# <option value="">All Industries</option>
# <option value="advertising-media-communications">Advertising, Media &amp; Communications</option>
# <option value="agriculture-fishing-forestry">Agriculture, Fishing &amp; Forestry</option>
# <option value="automotive-aviation">Automotive &amp; Aviation</option>
# <option value="banking-finance-insurance">Banking, Finance &amp; Insurance</option>
# <option value="construction">Construction</option>
# <option value="education">Education</option>
# <option value="energy-utilities">Energy &amp; Utilities</option>
# <option value="enforcement-security">Enforcement &amp; Security</option>
# <option value="entertainment-events-sport">Entertainment, Events &amp; Sport</option>
# <option value="government">Government</option>
# <option value="healthcare">Healthcare</option>
# <option value="hospitality-hotel">Hospitality &amp; Hotel</option>
# <option value="it-telecoms">IT &amp; Telecoms</option>
# <option value="law-compliance">Law &amp; Compliance</option>
# <option value="manufacturing-warehousing">Manufacturing &amp; Warehousing</option>
# <option value="mining-energy-metals">Mining, Energy &amp; Metals</option>
# <option value="ngo-npo-charity">NGO, NPO &amp; Charity</option>
# <option value="real-estate">Real Estate</option>
# <option value="recruitment">Recruitment</option>
# <option value="retail-fashion-fmcg">Retail, Fashion &amp; FMCG</option>
# <option value="shipping-logistics">Shipping &amp; Logistics</option>
# <option value="tourism-travel">Tourism &amp; Travel</option>
# <option value="unspecified">Unspecified</option>
# </select>
# <select aria-label="Select a location" class="w-full h-10 pl-2 text-gray-500 rounded-md border border-gray-300 hover:border-gray-400 focus:border-gray-400 placeholder-gray-400 focus:placeholder-gray-900 mb-3 w-full md:mb-0 md:mr-3" name="location" style="">
# <option value="">All Locations</option>
# <option value="abeokuta-ogun">Abeokuta &amp; Ogun State</option>
# <option value="abuja">Abuja</option>
# <option value="enugu">Enugu</option>
# <option value="ibadan-oyo">Ibadan &amp; Oyo State</option>
# <option value="imo">Imo</option>
# <option value="lagos">Lagos</option>
# <option value="maiduguri-borno">Maiduguri &amp; Borno State</option>
# <option value="port-harcourt-rivers">Port Harcourt &amp; Rivers State</option>
# <option value="rest-nigeria">Rest of Nigeria</option>
# <option value="outside-nigeria">Outside Nigeria</option>
# <option value="remote">Remote (Work From Home)</option>
# </select>
# <select aria-label="Select an experience level" class="w-full h-10 pl-2 text-gray-500 rounded-md border border-gray-300 hover:border-gray-400 focus:border-gray-400 placeholder-gray-400 focus:placeholder-gray-900 mb-3 w-full md:mb-0 md:mr-3" name="experience" style="">
# <option value="">All Experience Levels</option>
# <option value="no-experience">No Experience</option>
# <option value="graduate-trainee">Internship &amp; Graduate</option>
# <option value="entry-level">Entry level</option>
# <option value="mid-level">Mid level</option>
# <option value="senior-level">Senior level</option>
# <option value="executive-level">Executive level</option>
# </select>
# <button class="flex items-center justify-center appearance-none font-medium text-center rounded-md text-base py-3 lg:py-2 px-6 bg-pri-default text-white focus:shadow-pri hover:bg-pri-hover w-full lg:w-1/2" type="submit">
# <span class="mr-2" data-cy="search-button-top">Search</span>
# </button>
# </form>
# <script>
#     const TopSearch = {
#         handleSubmit: function(event) {
#             event.preventDefault();
#             event.stopPropagation();
#
#             const form = event.target;
#
#             const getValue = (name) => {
#                 if (form[name]) {
#                     if (form[name].type) {
#                         if (["select-one", "text", "hidden"].indexOf(form[name].type) > -1) {
#                             return form[name].value;
#                         } if (["checkbox", "radio"].indexOf(form[name].type) > -1 && form[name].checked) {
#                             return form[name].value;
#                         }
#                     } else if (form[name].length) {
#                         return form[name].value;
#                     }
#                 }
#
#                 return "";
#             };
#
#             const experienceLevel = getValue("experience[]") || getValue("experience");
#             const jobFunction = getValue("job_function[]") || getValue("job_function");
#             const industry = getValue("industry[]") || getValue("industry");
#             const location = getValue("location[]") || getValue("location");
#             const workType = getValue("work_type");
#             const term = getValue("q");
#             const sortBy = getValue("sort_by");
#
#             // If the logged in user is authenticated
#             // Append authenticated value to make url unique/different to logged out url
#             // same action is happening in SearchFilterViewComposer
#             // line 589 in the multiSearchFilterHref function
#             const authenticated = document.getElementById("authenticated").value;
#             let toUrl = "";
#             if (industry.trim() && jobFunction.trim()) {
#                 const segments = [jobFunction, location, workType].filter((x) => x);
#                 toUrl = `${segments.join("/")}?industry=${industry}`;
#             } else {
#                 const segments = [jobFunction, industry, location, workType].filter((x) => x);
#                 toUrl = segments.join("/");
#             }
#
#             if (experienceLevel) {
#                 toUrl += `${toUrl.indexOf("?") === -1 ? "?" : "&"}experience=${experienceLevel}`;
#             }
#
#             if (term.trim()) {
#                 toUrl += `${toUrl.indexOf("?") === -1 ? "?" : "&"}q=${encodeURI(term.replace(" ", "+"))}`;
#             }
#
#             if (sortBy.trim()) {
#                 toUrl += `${toUrl.indexOf("?") === -1 ? "?" : "&"}sort=${sortBy}`;
#             }
#
#             if (authenticated === "true") {
#                 toUrl += `${toUrl.indexOf("?") === -1 ? "?" : "&"}authenticated=${Date.now()}`;
#             }
#
#             const wholeUrl = `${form.getAttribute("action")}/${toUrl.toLocaleLowerCase()}`;
#             window.location.assign(wholeUrl.replace(/\/$/, ""));
#
#             return false;
#         }
#     };
# </script>
# </div>
# </div>
# <div>
# <div class="sticky z-20 py-3 px-5 bg-gray-100 shadow transition duration-300 md:hidden" style="top: 60px;">
# <a class="flex items-center justify-center appearance-none font-medium text-center rounded-md text-base py-3 lg:py-2 px-6 bg-pri-default text-white focus:shadow-pri hover:bg-pri-hover block w-full text-center" href="https://www.jobberman.com/account/login" x-data="">
# Log In and Apply
# </a>
# </div>
# <div class="no-plain-mode">
# <nav class="w-full mb-5 rounded-md py-3 px-3 lg:px-0 lg:pl-[50px]">
# <ol class="flex flex-wrap text-sm list-reset">
# <li>
# <a class="text-link-400" href="https://www.jobberman.com"><svg aria-hidden="true" class="fill-link-500" fill="#004AB9" height="22" role="presentation" viewbox="0 0 24 24" width="22"><path d="M10 20v-6h4v6h5v-8h3L12 3 2 12h3v8h5z"></path></svg></a>
# </li>
# <li><span class="mx-4 text-gray-500">/</span></li>
# <li>
# <a class="text-link-500" href="/jobs/software-data">Software &amp; Data</a>
# </li>
# <li><span class="mx-4 text-gray-500">/</span></li>
# <li>
# <a class="text-link-500" href="/jobs/software-data?industry=banking-finance-insurance">Banking, Finance &amp; Insurance</a>
# </li>
# <li><span class="mx-4 text-gray-500">/</span></li>
# <li>
# <a class="text-link-500" href="/jobs/software-data/remote?industry=banking-finance-insurance">Remote (Work From Home)</a>
# </li>
# <li><span class="mx-4 text-gray-500">/</span></li>
# <li>
# <a class="text-link-500" href="/jobs/software-data/remote/full-time?industry=banking-finance-insurance">Full Time</a>
# </li>
# <li><span class="mx-4 text-gray-500">/</span></li>
# <li class="text-gray-500">Backend Developer</li>
# </ol>
# </nav>
# </div>
# <div class="md:flex md:justify-between">
# <div class="w-full md:grow md:mx-[50px]">
# <div class="border-gray-200 dark:border-gray-700 md:container mt-5" x-data="{ tab: 'tab1' }">
# <div class="mb-5">
# <ul class="flex px-5 md:mx-0 flex-wrap md:-mb-px h-14 list-none border-t border-b md:rounded-lg md:border border-gray-300 hover:border-gray-400" role="tablist">
# <li class="md:ml-5" role="presentation">
# <a :class="{ 'active border-brand-primary active text-brand-primary hover:border-brand-primary hover:text-brand-primary': tab === 'tab1' }" class="px-2 font-medium text-sm text-center text-gray-500 rounded-t-lg border-b-2 border-transparent hover:text-gray-500 h-full flex items-center" href="#tab1" role="tab" title="Job Details" x-on:click.prevent="tab = 'tab1'">Job Details</a>
# </li>
# <li class="md:ml-5" role="presentation">
# <a :class="{ 'active border-brand-primary active text-brand-primary hover:border-brand-primary hover:text-brand-primary': tab === 'tab2' }" class="px-2 font-medium text-sm text-center text-gray-500 rounded-t-lg border-b-2 border-transparent hover:text-gray-500 h-full flex items-center" href="#tab2" id="similar-listings-tab" role="tab" title="Similar Jobs" x-on:click.prevent="tab = 'tab2'">Similar Jobs</a>
# </li>
# </ul>
# </div>
# <div class="tab-content">
# <div class="tab-pane fade show" id="tab1" role="tabpanel" title="Job Details" x-show="tab === 'tab1'">
# <div class="flex flex-col rounded-lg border-gray-300 md:border hover:border-gray-400 md:mx-0">
# <article class="job__details" data-job-id="947420">
# <div class="flex flex-wrap justify-start items-center p-3 pt-0 md:pt-3 border-b border-gray-300">
# <div>
# </div>
# </div>
# <div class="flex flex-wrap justify-start pt-5 pb-2 px-4 w-full border-b border-gray-300 md:flex-nowrap md:px-5">
# <div class="mr-6 flex-shrink-0">
# <a href="/company/jobberman-sales-account">
# <div class="flex justify-center items-center p-1 w-[100px] h-[100px] align-middle bg-white rounded-md border-2 border-gray-300">
# <img alt="Jobberman (Third Party Recruitment)" class="w-full h-full object-contain transition-opacity duration-200 ease-in rounded" height="85" loading="lazy" src="https://i.roamcdn.net/kazi/ng/hq/7ba14d36d8fb4ba479270fceb0feb4b8/-/advertiser-img-ng-jobs-prod/dealer-images/advid3919/adv3919_1629907145.jpg" width="85"/>
# </div>
# </a></div>
# <div class="w-full text-gray-500">
# <h1 class="mt-6 mb-3 text-lg font-medium text-gray-700 md:mb-4 md:mt-0" data-cy="title-job">Backend Developer</h1>
# <h2 class="pb-1 text-sm font-normal">
# <a class="text-link-500" href="/company/jobberman-sales-account">
# Jobberman (Third Party Recruitment)
# </a>
# </h2>
# <h2 class="text-sm font-normal">
# <a href="https://www.jobberman.com/jobs/software-data">
# Software &amp; Data
# </a>
# </h2>
# <div class="mt-3">
# <a class="text-sm font-normal px-3 rounded bg-brand-secondary-50 mr-2 mb-3 inline-block" href="https://www.jobberman.com/jobs/remote-work-from-home">
# Remote (Work From Home)
# </a>
# <span class="text-sm font-normal px-3 rounded bg-brand-secondary-50 mr-2 mb-3 inline-block">
# <a href="https://www.jobberman.com/jobs/full-time">Full Time</a>
# </span>
# </div>
# <div>
# <a class="text-sm font-normal px-3 rounded bg-brand-secondary-50 mr-2 mb-3 inline-block" href="https://www.jobberman.com/jobs/banking-finance-insurance">
# Banking, Finance &amp; Insurance
# </a>
# <span class="text-sm font-normal px-3 rounded bg-brand-secondary-50 mr-2 mb-3 inline-block">
# <span>
# NGN
# </span>
# Confidential
# </span>
# </div>
# </div>
# </div>
# <div class="sm:flex sm:flex-wrap justify-start py-5 px-4 w-full border-b border-gray-300 md:flex-nowrap md:px-5">
# <div class="pb-3 sm:pb-0">
# <span class="inline-flex items-center px-3 py-0.5 rounded-full text-xs md:text-sm font-normal bg-green-100 text-green-500 capitalize mr-2">
# New
# <svg class="ml-2" fill="none" height="14" viewbox="0 0 14 14" width="14" xmlns="http://www.w3.org/2000/svg">
# <path d="M7 1.75V2.33333M7 11.6667V12.25M12.25 7H11.6667M2.33333 7H1.75M10.7123 10.7123L10.2998 10.2998M3.70017 3.70017L3.28769 3.28769M10.7123 3.28772L10.2999 3.7002M3.7002 10.2999L3.28772 10.7123M9.33333 7C9.33333 8.28866 8.28866 9.33333 7 9.33333C5.71134 9.33333 4.66667 8.28866 4.66667 7C4.66667 5.71134 5.71134 4.66667 7 4.66667C8.28866 4.66667 9.33333 5.71134 9.33333 7Z" stroke="#389660" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.5"></path>
# </svg>
# </span>
# <span class="inline-flex items-center px-3 py-0.5 rounded-full text-xs md:text-sm font-normal bg-red-100 text-red-600 capitalize mr-2">
# Featured
# <svg class="ml-2" fill="none" height="12" viewbox="0 0 12 12" width="12" xmlns="http://www.w3.org/2000/svg">
# <path d="M7.85008 3.08333L4.00837 6.92504C3.55276 7.38065 3.55276 8.11935 4.00837 8.57496C4.46398 9.03057 5.20267 9.03057 5.65829 8.57496L9.39991 4.73325C10.3111 3.82203 10.3111 2.34464 9.39991 1.43342C8.48869 0.522194 7.0113 0.522194 6.10008 1.43342L2.35845 5.27513C0.991619 6.64196 0.991619 8.85804 2.35845 10.2249C3.72529 11.5917 5.94137 11.5917 7.3082 10.2249L10.9583 6.58333" stroke="#D42B3D" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.5"></path>
# </svg>
# </span>
# </div>
# <div class="flex relative justify-end pl-3 text-gray-500 font-sm ml-auto">
# 4 days ago
# </div>
# </div>
# <div class="py-5 px-4 border-b border-gray-300 md:p-5">
# <h3 class="mb-3 text-lg font-medium text-gray-700">
# Job Summary
# </h3>
# <p class="mb-4 text-sm text-gray-500">
# As a full backend developer for websites and apps, your role would involve building and maintaining the server-side components that power both platforms. Here's an overview of your responsibilities:
# </p>
# <ul class="pl-5 text-sm list-disc text-gray-500">
# <li>
# <span class="text-gray-700 min-w-[200px] inline-flex pb-1 font-medium">Minimum Qualification:</span>
# <span class="pb-1 text-gray-500">HND</span>
# </li>
# <li>
# <span class="text-gray-700 pb-1 min-w-[200px] inline-flex font-medium">Experience Level:</span>
# <span class="pb-1 text-gray-500">Mid level</span>
# </li>
# <li>
# <span class="text-gray-700 pb-1 min-w-[200px] inline-flex font-medium">Experience Length:</span>
# <span class="pb-1 text-gray-500">2 years</span>
# </li>
# </ul>
# </div>
# <div class="py-5 px-4 border-b border-gray-300 md:p-5">
# <h3 class="mb-3 text-lg font-medium text-gray-700">
# Job Description/Requirements
# </h3>
# <div class="text-sm text-gray-500" style="word-break: break-word;">
# <p><b>Responsibilities:</b></p>
# <ul class="list-disc list-inside"><li style="word-break: break-word;">Designing and developing scalable, secure, and efficient backend systems for websites and apps.</li><li style="word-break: break-word;">Building and maintaining APIs to facilitate seamless communication between the frontend interfaces and the backend services.</li><li style="word-break: break-word;">Implementing robust user authentication and authorization mechanisms to ensure secure access to website and app features.</li><li style="word-break: break-word;">Integrating with third-party services and APIs, such as payment gateways, social media platforms, or cloud storage providers.</li><li style="word-break: break-word;">Optimizing database management and employing efficient data storage techniques to handle the website and app-related data.</li><li style="word-break: break-word;">Collaborating closely with frontend developers to ensure smooth integration and functionality between the frontend and backend.</li><li style="word-break: break-word;">Conducting thorough testing and debugging to identify and resolve any backend-related issues.</li><li style="word-break: break-word;">Staying up-to-date with the latest web and app development technologies, frameworks, and industry best practices.</li><li style="word-break: break-word;">Working closely with the project team to gather requirements, provide technical insights, and contribute to project planning.</li></ul>
# <p><br/></p>
# <p><b>Requirements:</b></p>
# <ul class="list-disc list-inside"><li style="word-break: break-word;">Minimum of 2 -3 years of working experience</li></ul>
# <p><br/></p>
# <p><b>Work Type:</b> Remote</p>
# </div>
# </div>
# <div class="flex flex-col py-5 px-4 border-b border-gray-300 md:p-5">
# <h3 class="mb-3 text-lg font-normal text-gray-700">
# Important Safety Tips
# </h3>
# <div class="flex flex-col mb-4">
# <ul class="pl-5 text-sm list-disc text-gray-500">
# <li class="text-sm text-gray-500">Do not make any payment without confirming with the Jobberman Customer Support Team.</li>
# <li class="text-sm text-gray-500">If you think this advert is not genuine, please report it via the Report Job link below.</li>
# </ul>
# </div>
# <a class="flex items-center justify-center appearance-none font-medium text-center rounded-md text-sm py-2 px-4 bg-white border border-pri-default text-pri-default focus:shadow-sec hover:bg-sec-hover w-fit" href="#0" id="btn_report_job" x-on:click.prevent="$store.global.modal = 'reportJobModal'">
# Report Job
# </a>
# </div>
# <div class="px-4 py-5 md:p-5 border-b border-gray-300 md:border-0">
# <h3 class="mb-3 text-lg font-normal text-gray-700">
# Share Job Post
# </h3>
# <div class="inline-flex relative flex-wrap">
# <div class="inline-flex flex-wrap">
# <input name="csrf-token" type="hidden" value="4OBlr4vkrswmQYhQhOohC5iEpsPeEPsfo2HUDdA6"/>
# <a class="mr-4 h-[40px] w-[40px] share__icon-link button--whatsapp metrics-share-job-whatsapp js-socialShareBox cursor-pointer" data-job-id="947420" data-social-share="" data-user-id="" href="https://wa.me/?text=Check+out+this+job+on+Jobberman%3A+Backend+Developer+https%3A%2F%2Fwww.jobberman.com%2Flistings%2Fbackend-developer-evdg2j%3Futm_medium%3Dsocial%26utm_campaign%3Dshare-button%26utm_source%3Dwhatsapp" onclick="window.dataLayer &amp;&amp; window.dataLayer.push({'event': 'share', 'source': 'whatsapp', 'link_url': 'https://www.jobberman.com/listings/backend-developer-evdg2j', 'method': 'whatsapp' });" rel="noopener noreferrer nofollow" target="_blank" title="Share Backend Developer on whatsapp">
# </a>
# <a class="mr-4 h-[40px] w-[40px] share__icon-link button--sms metrics-share-job-sms cursor-pointer" data-job-id="947420" data-user-id="" id="smsShare" title="Share Backend Developer via sms" x-on:click="$store.global.modal = 'shareJobSMSModal'">
# </a>
# <a class="mr-4 h-[40px] w-[40px] share__icon-link button--linkedin metrics-share-job-linkedin js-socialShareBox cursor-pointer" data-job-id="947420" data-social-share="" data-user-id="" href="https://www.linkedin.com/shareArticle/?mini=true&amp;ro=true&amp;url=https%3A%2F%2Fwww.jobberman.com%2Flistings%2Fbackend-developer-evdg2j%3Futm_medium%3Dsocial%26utm_campaign%3Dshare-button%26utm_source%3Dlinkedin&amp;title=Backend+Developer" onclick="window.dataLayer &amp;&amp; window.dataLayer.push({'event': 'share', 'source': 'linkedin', 'link_url': 'https://www.jobberman.com/listings/backend-developer-evdg2j', 'method': 'linkedin' });" rel="noopener noreferrer nofollow" target="_blank" title="Share Backend Developer on linkedin">
# </a>
# ...
# <option value="WF">Wallis and Futuna Islands (+681)</option>
# <option value="EH">Western Sahara (+212)</option>
# <option value="YE">Yemen (+967)</option>
# <option value="ZM">Zambia (+260)</option>
# <option value="ZW">Zimbabwe (+263)</option>
# <option value="AX">Ãland Islands (+358)</option>
# </select>
# </div>
# <div class="text-left w-1/2">
# <input class="h-10 py-3 px-2 box-border rounded-md hover:border-gray-400 focus:border-gray-400 text-gray-700 block w-full outline-none focus:ring-0 placeholder-gray-400 focus:placeholder-gray-400 font-normal border-gray-300" data-parsley-error-message="Please enter your mobile number" id="mobile_number" name="mobile_number" placeholder="Mobile Number" required="true" type="text"/>
# </div>
# </div>
# <div class="flex flex-col mt-5 w-full">
# <textarea class="py-3 px-2 box-border rounded-md hover:border-gray-400 focus:border-gray-400 text-gray-700 block w-full outline-none focus:ring-0 placeholder-gray-400 focus:placeholder-gray-400 font-normal border-gray-300 text-gray-400" disabled="true" id="comment" maxlength="200" name="comment" style="white-space: normal;" type="text">I saw this job posted on https://www.jobberman.com/listings/backend-developer-evdg2j and thought you might be interested in it.</textarea>
# </div>
# </div>
# </div>
# <div class="flex flex-col space-y-4 mt-5 px-4 md:flex-row md:space-y-0 md:justify-end md:space-x-5 md:px-5 max-lg:rounded-b-md pb-4">
# <div class="flex flex-col space-y-4 w-full md:space-y-0 md:space-x-4 md:flex-row">
# <button class="flex items-center justify-center appearance-none font-medium text-center rounded-md text-base py-3 lg:py-2 px-6 bg-white border border-pri-default text-pri-default focus:shadow-sec hover:bg-sec-hover w-full" type="button" x-on:click="$store.global.modal = ''">
# Back
# </button>
# <button class="flex items-center justify-center appearance-none font-medium text-center rounded-md text-base py-3 lg:py-2 px-6 bg-pri-default text-white focus:shadow-pri hover:bg-pri-hover w-full" id="submit" onclick="window.dataLayer &amp;&amp; window.dataLayer.push({'event': 'share', 'source': 'sms', 'link_url': 'https://www.jobberman.com/listings/backend-developer-evdg2j', 'method': 'sms' });" type="submit">
# Send
# </button>
# </div>
# </div>
# </div>
# </div>
# </form>
# </div>
# <script>
#     function handleClickAway(event) {
#         event.stopPropagation();
#         this.$store.global.modal = '';
#     }
# </script>
# <div x-cloak="" x-data="{ handleClickAway: handleClickAway }" x-show="$store.global.modal === 'preview-cv-modal'">
# <div class="bg-black bg-opacity-40 fixed flex flex-col h-full items-center sm:items-center z-50 overflow-y-auto top-0 left-0 justify-center w-full sm:px-4 lg:px-4">
# <div @click.away="handleClickAway" class="flex flex-col shadow bg-white sm:rounded-lg overflow-y-auto h-full sm:h-fit w-full" data-cy="modal-container" x-bind:class="$store.global.isSideMenuOpen ? 'md:max-w-md xl:max-w-xl' : 'md:max-w-3xl'" x-transition:enter="transition ease duration-100 transform" x-transition:enter-end="opacity-100 scale-100 translate-y-0" x-transition:enter-start="opacity-0 scale-90 translate-y-1" x-transition:leave="transition ease duration-100 transform" x-transition:leave-end="opacity-0 scale-90 translate-y-1" x-transition:leave-start="opacity-100 scale-100 translate-y-0">
# <div class="flex-row justify-end px-4 pt-4 flex md:px-5 rounded-t-md">
# <button data-cy="close-button-modal" type="button" x-on:click="() =&gt; {$store.global.modal = '';  ;}">
# <svg fill="none" height="16" viewbox="0 0 16 16" width="16" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M1.15147 1.15152C1.6201 0.682892 2.3799 0.682892 2.84853 1.15152L8 6.30299L13.1515 1.15152C13.6201 0.682892 14.3799 0.682892 14.8485 1.15152C15.3172 1.62015 15.3172 2.37995 14.8485 2.84858L9.69706 8.00005L14.8485 13.1515C15.3172 13.6202 15.3172 14.3799 14.8485 14.8486C14.3799 15.3172 13.6201 15.3172 13.1515 14.8486L8 9.69711L2.84853 14.8486C2.3799 15.3172 1.6201 15.3172 1.15147 14.8486C0.682846 14.3799 0.682846 13.6202 1.15147 13.1515L6.30295 8.00005L1.15147 2.84858C0.682846 2.37995 0.682846 1.62015 1.15147 1.15152Z" fill="#111827" fill-rule="evenodd"></path>
# </svg>
# </button>
# </div>
# <div class="w-full justify-center flex mt-4 px-4 md:px-5 md:pb-0">
# </div>
# <div class="w-full flex-col flex mt-4 px-4 md:px-5">
# <p>Preview CV</p>
# </div>
# <div class="flex flex-col space-y-4 mt-5 px-4 md:flex-row md:space-y-0 md:justify-end md:space-x-5 md:px-5 max-lg:rounded-b-md pb-4">
# </div>
# </div>
# </div>
# </div>
# <script>
#     function handleClickAway(event) {
#         event.stopPropagation();
#         this.$store.global.modal = '';
#     }
# </script>
# </div>
# </section>
# </main>
# <div class="flex" style="" x-bind:class="{
#             'lg:ml-[300px]': Boolean() &amp;&amp; $store.global.isSideMenuOpen,
#             'lg:ml-[80px]': Boolean() &amp;&amp; !$store.global.isSideMenuOpen
#         }" x-data="" x-init="$nextTick(() =&gt; $el.style.removeProperty('margin-left'))">
# <div class="float-left w-full relative border-[rgba(0,0,0,0.05)] border-t-2">
# <div class="flex flex-col container relative pt-[60px]">
# <div class="flex flex-col flex-wrap justify-between items-center w-full md:flex-row">
# <a class="py-2 text-sm text-link-500" data-cy="about-nav-footer" href="https://www.jobberman.com/about">
# About
# </a>
# <span class="hidden text-gray-300 gray-dash md:block">|</span>
# <a class="py-2 text-sm text-link-500" href="https://www.jobberman.com/companies">
# Companies Hiring
# </a>
# <span class="hidden text-gray-300 gray-dash md:block">|</span>
# <a class="py-2 text-sm text-link-500" href="https://www.jobberman.com/privacy-policy">
# Privacy Policy
# </a>
# <span class="hidden text-gray-300 md:block gray-dash">|</span>
# <a class="py-2 text-sm text-link-500" href="https://www.jobberman.com/terms">
# Terms
# </a>
# <span class="hidden text-gray-300 gray-dash md:block">|</span>
# <a class="py-2 text-sm text-link-500" href="https://www.jobberman.com/account/cv-services">
# CV Review Services
# </a>
# <span class="hidden text-gray-300 gray-dash md:block">|</span>
# <a class="py-2 text-sm text-link-500" href="https://www.jobberman.com/softskills">
# Soft Skills Training
# </a>
# <span class="hidden text-gray-300 gray-dash md:block">|</span>
# <a class="py-2 text-sm text-link-500" href="https://www.jobberman.com/employer/skills-assessments">
# Skills Assessments
# </a>
# <span class="hidden text-gray-300 gray-dash md:block">|</span>
# <a class="py-2 text-sm text-link-500" download="" href="https://static.jobberman.com/banner-rate-card-nigeria.pdf" rel="noopener noreferrer" target="_blank">
# Banner Rate Card
# </a>
# <span class="hidden text-gray-300 gray-dash md:block">|</span>
# </div>
# <div class="flex flex-row justify-center md:justify-start">
# <span class="pt-5 text-sm text-gray-700">
# Follow us On:
# </span>
# </div>
# <div class="flex flex-row justify-center md:justify-start items-center py-5 w-full">
# <a class="mr-4" href="https://www.facebook.com/jobbermannigeria">
# <img alt="Follow us on Facebook" height="32" loading="lazy" src="/build/static-assets/img/icon-facebook.a8ffd853.svg" width="32"/>
# </a>
# <a class="mr-4" href="https://www.instagram.com/jobbermannigeria/">
# <img alt="Follow us on Instagram" height="32" loading="lazy" src="/build/static-assets/img/icon-instagram.f94aacd6.svg" width="32"/>
# </a>
# <a class="mr-4" href="https://www.linkedin.com/company/jobberman">
# <img alt="Follow us on LinkedIn" height="32" loading="lazy" src="/build/static-assets/img/icon-linkedin.26a3db8e.svg" width="32"/>
# </a>
# <a class="mr-4" href="https://www.twitter.com/jobbermandotcom">
# <img alt="Follow us on Twitter" height="32" loading="lazy" src="/build/static-assets/img/icon-twitter.6b47ac5c.svg" width="32"/>
# </a>
# <a class="mr-0 md:mr-4" href="https://www.youtube.com/Jobbermandotcom">
# <img alt="Follow us on YouTube" height="32" loading="lazy" src="/build/static-assets/img/icon-youtube.bd29b086.svg" width="32"/>
# </a>
# <a class="mr-0 md:mr-4" href="https://api.whatsapp.com/send/?phone=2348097202945&amp;text=Hi&amp;type=phone_number&amp;app_absent=0">
# <img alt="Chat with us on Whatsapp" height="32" loading="lazy" src="/build/static-assets/img/icon-whatsapp.611566a5.svg" width="32"/>
# </a>
# <a class="hidden md:block" href="https://play.google.com/store/apps/details?id=com.jobberman&amp;utm_source=jobberman.com&amp;utm_campaign=google-play-badge&amp;pcampaignid=MKT-Other-global-all-co-prtnr-py-2artBadge-Mar2515-1" rel="noopener noreferrer">
# <img alt="Get it on Google Play" height="70" loading="lazy" src="/build/static-assets/img/play-badge.f8a9ba04.png" style="width: 180px;" width="180"/>
# </a>
# </div>
# <a class="block self-center py-5 md:hidden" href="https://play.google.com/store/apps/details?id=com.jobberman&amp;utm_source=jobberman.com&amp;utm_campaign=google-play-badge&amp;pcampaignid=MKT-Other-global-all-co-prtnr-py-2artBadge-Mar2515-1" rel="noopener noreferrer">
# <img alt="Get it on Google Play" height="70" loading="lazy" src="/build/static-assets/img/play-badge.f8a9ba04.png" style="width: 180px;" width="180"/>
# </a>
# <div class="flex flex-row justify-center items-center py-5 w-full border-t-2 border-gray-300">
# <span class="pr-2">
# <svg aria-hidden="true" class="text-gray-500" enable-background="new 0 0 24 24" fill="#9CA3AF" height="18" role="presentation" viewbox="0 0 24 24" width="18" xmlns="http://www.w3.org/2000/svg"><g><rect fill="none" height="24" width="24" x="0"></rect></g><g><g><g><path d="M11.88,9.14c1.28,0.06,1.61,1.15,1.63,1.66h1.79c-0.08-1.98-1.49-3.19-3.45-3.19C9.64,7.61,8,9,8,12.14 c0,1.94,0.93,4.24,3.84,4.24c2.22,0,3.41-1.65,3.44-2.95h-1.79c-0.03,0.59-0.45,1.38-1.63,1.44C10.55,14.83,10,13.81,10,12.14 C10,9.25,11.28,9.16,11.88,9.14z M12,2C6.48,2,2,6.48,2,12s4.48,10,10,10s10-4.48,10-10S17.52,2,12,2z M12,20c-4.41,0-8-3.59-8-8 s3.59-8,8-8s8,3.59,8,8S16.41,20,12,20z"></path></g></g></g></svg> </span>
# <span class="text-base font-medium text-gray-500">
# 2023 Jobberman
# </span>
# </div>
# </div>
# </div>
# </div>
# <script src="https://www.jobberman.com/build/assets/scripts/mini-xhr.umd.min.6cc6f550.js"></script>
# <script async="" src="https://www.jobberman.com/build/assets/scripts/app.1d56e485.js"></script>
# <script>
#             window.recaptchaValid = () => {
#                 if (window.alpine_component("recaptcha-login")
#                     .validate()) {
#                     document.querySelector("#recaptcha-login")
#                         .submit();
#                 }
#             };
#         </script>
# <script src="https://www.jobberman.com/build/assets/scripts/recaptcha.7427cd9c.js"></script>
# <script>
#     var __gtmDataLayer = [{"event":"view_item","ecommerce.items.0":{"item_name":"Backend Developer","item_id":947420,"affiliation":"Jobberman (Third Party Recruitment)","item_brand":"classified listing","item_category":"Software & Data","item_category3":"Full Time","item_variant":"salary confidential","location_id":"Remote (Work From Home)","price":1,"quantity":1}}];
#     if (__gtmDataLayer && !Array.isArray(__gtmDataLayer)) {
#         if (window) {
#             window.dataLayer = window.dataLayer || [];
#             for (var i=0; i<__gtmDataLayer.length; i++) {
#                 window.dataLayer.push(__gtmDataLayer[i]);
#             }
#         }
#     }
# </script>
# <script type="application/ld+json">{
#     "@context": "https://schema.org",
#     "@type": "BreadcrumbList",
#     "itemListElement": [
#         {
#             "@type": "ListItem",
#             "position": 1,
#             "item": {
#                 "@id": "https://www.jobberman.com",
#                 "name": "Homepage",
#                 "image": "https://www.jobberman.com/build/static-assets/img/jobberman-theme/opengraph-logo-small.0957cff5.png"
#             }
#         },
#         {
#             "@type": "ListItem",
#             "position": 2,
#             "item": {
#                 "@id": "https://www.jobberman.com/jobs/software-data",
#                 "name": "Software & Data",
#                 "image": "https://www.jobberman.com/build/static-assets/img/jobberman-theme/opengraph-logo-small.0957cff5.png"
#             }
#         },
#         {
#             "@type": "ListItem",
#             "position": 3,
#             "item": {
#                 "@id": "https://www.jobberman.com/jobs/banking-finance-insurance",
#                 "name": "Banking, Finance & Insurance",
#                 "image": "https://www.jobberman.com/build/static-assets/img/jobberman-theme/opengraph-logo-small.0957cff5.png"
#             }
#         },
#         {
#             "@type": "ListItem",
#             "position": 4,
#             "item": {
#                 "@id": "https://www.jobberman.com/jobs/remote",
#                 "name": "Remote (Work From Home)",
#                 "image": "https://www.jobberman.com/build/static-assets/img/jobberman-theme/opengraph-logo-small.0957cff5.png"
#             }
#         },
#         {
#             "@type": "ListItem",
#             "position": 5,
#             "item": {
#                 "@id": "https://www.jobberman.com/jobs/full-time",
#                 "name": "Full Time",
#                 "image": "https://www.jobberman.com/build/static-assets/img/jobberman-theme/opengraph-logo-small.0957cff5.png"
#             }
#         },
#         {
#             "@type": "ListItem",
#             "position": 6,
#             "item": {
#                 "@id": "https://www.jobberman.com/listings/backend-developer-evdg2j/",
#                 "name": "Backend Developer",
#                 "image": "https://i.roamcdn.net/kazi/ng/base/ca843051a47bfbedfbebaf5d2732bda3/-/advertiser-img-ng-jobs-prod/dealer-images/advid3919/adv3919_1629907145.jpg"
#             }
#         }
#     ]
# }</script>
# <script type="application/ld+json">{
#     "@context": "https://schema.org/",
#     "@type": "JobPosting",
#     "title": "Backend Developer",
#     "description": "<p><b>Responsibilities:</b></p>\n\n<ul><li>Designing and developing scalable, secure, and efficient backend systems for websites and apps.</li><li>Building and maintaining APIs to facilitate seamless communication between the frontend interfaces and the backend services.</li><li>Implementing robust user authentication and authorization mechanisms to ensure secure access to website and app features.</li><li>Integrating with third-party services and APIs, such as payment gateways, social media platforms, or cloud storage providers.</li><li>Optimizing database management and employing efficient data storage techniques to handle the website and app-related data.</li><li>Collaborating closely with frontend developers to ensure smooth integration and functionality between the frontend and backend.</li><li>Conducting thorough testing and debugging to identify and resolve any backend-related issues.</li><li>Staying up-to-date with the latest web and app development technologies, frameworks, and industry best practices.</li><li>Working closely with the project team to gather requirements, provide technical insights, and contribute to project planning.</li></ul>\n\n<p><br></p>\n\n<p><b>Requirements:</b></p>\n\n<ul><li>Minimum of 2 -3 years of working experience</li></ul>\n\n<p><br></p>\n\n<p><b>Work Type:</b> Remote</p>",
#     "datePosted": "2023-11-14T14:23:28+00:00",
#     "validThrough": "2024-01-12T00:00:00+00:00",
#     "employmentType": "FULL_TIME",
#     "industry": "Banking, Finance & Insurance",
#     "occupationalCategory": "Software & Data",
#     "educationRequirements": {
#         "@type": "EducationalOccupationalCredential",
#         "credentialCategory": "associate degree"
#     },
#     "qualifications": "Mid level",
#     "experienceRequirements": {
#         "@type": "OccupationalExperienceRequirements",
#         "monthsOfExperience": 24
#     },
#     "jobLocationType": "TELECOMMUTE",
#     "applicantLocationRequirements": {
#         "@type": "Country",
#         "name": "NG"
#     },
#     "hiringOrganization": {
#         "@type": "Organization",
#         "name": "Jobberman (Third Party Recruitment)",
#         "sameAs": "",
#         "logo": "https://i.roamcdn.net/kazi/ng/base/ca843051a47bfbedfbebaf5d2732bda3/-/advertiser-img-ng-jobs-prod/dealer-images/advid3919/adv3919_1629907145.jpg"
#     }
# }</script>
# </body>
# </html>

# %%
#get jobtitle
job_title = new_soup.find("h1", attrs={"class":'mt-6 mb-3 text-lg font-medium text-gray-700 md:mb-4 md:mt-0'}).text
print(job_title)
# Out:
# Backend Developer

# %%
#get job description
job_description = new_soup.find("p", attrs={"class":'mb-4 text-sm text-gray-500'}).text.strip()
print(job_description)
# Out:
# As a full backend developer for websites and apps, your role would involve building and maintaining the server-side components that power both platforms. Here's an overview of your responsibilities:

# %%
#get job requirement
new_soup.find("li", attrs={"style":'word-break: break-word;'})

for li in new_soup.find_all("li", attrs={"style":'word-break: break-word;'}):
    if 'experience' in li.text:
        print(li.text)
# Out:
# Minimum of 2 -3 years of working experience

# %%
#Job type
#get job type
job_type = new_soup.find("a", attrs={"class":'text-sm font-normal px-3 rounded bg-brand-secondary-50 mr-2 mb-3 inline-block'}).text.strip()
print(job_type)
# Out:
# Remote (Work From Home)

# %%
#Industry
# Find all elements with the same class
sector = new_soup.find_all("a", attrs={"class":'text-sm font-normal px-3 rounded bg-brand-secondary-50 mr-2 mb-3 inline-block'})

# Check if there are at least two elements
if len(sector) >= 2:
    # Get the second element
    industry = sector[1].text
    print(industry)
else:
    print("no industry")
# Out:
# Banking, Finance & Insurance

# %%
#Salary
# Find all elements with the same class
pay = new_soup.find_all("span", attrs={"class":'text-sm font-normal px-3 rounded bg-brand-secondary-50 mr-2 mb-3 inline-block'})

# Check if there are at least two elements
if len(pay) >= 2:
    # Get the second element
    salary = pay[1].text.strip()
    print(salary)
else:
    print("no salary")
# Out:
# NGN
#
# Confidential

# %%
# Function to extract Job Title
def get_title(soup):
    try:
        title = soup.find("h1", attrs={"class":'mt-6 mb-3 text-lg font-medium text-gray-700 md:mb-4 md:mt-0'})
        title_value = title.text
        title_string = title_value.strip()
    except AttributeError:
        title_string = ""
    return title_string

# Function to extract Job Description
def get_description(soup):
    try:
        description = soup.find("p", attrs={"class":'mb-4 text-sm text-gray-500'}).text.strip()
    except AttributeError:
        description = ""
    return description

# Function to extract Job Requirement
def get_requirement(soup):
    requirement = ""
    try:
        for li in soup.find_all("li", attrs={"style":'word-break: break-word;'}):
            if 'experience' in li.text:
                requirement = li.text
    except AttributeError:
        requirement = ""
    return requirement

# Function to extract Job_type
def get_job_type(soup):
    try:
        job_type = soup.find("a", attrs={"class":'text-sm font-normal px-3 rounded bg-brand-secondary-50 mr-2 mb-3 inline-block'}).text.strip()
    except AttributeError:
        job_type = ""	
    return job_type

# Function to extract industry
def get_industry(soup):
    industry = ""
    try:
        sector = soup.find_all("a", attrs={"class":'text-sm font-normal px-3 rounded bg-brand-secondary-50 mr-2 mb-3 inline-block'})
        if len(sector) >= 2:
            industry = sector[1].text.strip()
    except AttributeError:
        industry = "no industry"
    return industry

# Function to extract salary
def get_salary(soup):
    salary = ""
    try:
        pay = soup.find_all("span", attrs={"class":'text-sm font-normal px-3 rounded bg-brand-secondary-50 mr-2 mb-3 inline-block'})
        if len(pay) >= 2:
            salary = pay[1].text.strip()
    except AttributeError:
        salary = "no salary"
    return salary

# %%
if __name__ == '__main__':
    
    #add your user agent
    HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0', 'Accept-Language':'en-US, en;q=0.5'})
    
    # The  webpage url
    URL = "https://www.jobberman.com/jobs/software-data?sort=featured"
    
    #http request
    webpage = requests.get(URL, headers=HEADERS)
    
    #soup object containinng
    soup = BeautifulSoup(webpage.content, "html.parser")
    
    #Fetch links 
    links = soup.find_all("a", attrs={'class':'relative mb-3 text-lg font-medium break-words focus:outline-none metrics-apply-now text-link-500 text-loading-animate'})
    
    links_list = []
    
    #Loop for extracting links from link list
    for link in links:
        links_list.append(link.get('href'))
    
    d = {"title":[], "description":[], "requirement":[], "job_type":[], "industry":[], "salary":[]}
    
    #Loop for extracting all job details from each link
    for link in links_list:
        new_webpage = requests.get(link, headers=HEADERS)
        
        new_soup = BeautifulSoup(new_webpage.content, "html.parser")
        
        
        #Functions to dislay all job details
        d['title'].append(get_title(new_soup))
        d['description'].append(get_description(new_soup))
        d['requirement'].append(get_requirement(new_soup))
        d['job_type'].append(get_job_type(new_soup))
        d['industry'].append(get_industry(new_soup))
        d['salary'].append(get_salary(new_soup))
    
    df = pd.DataFrame.from_dict(d)
    df['title'].replace('', np.nan, inplace=True)
    df = df.dropna(subset=['title'])
    df.to_csv("jobberman_data.csv", header=True, index=False)

# %%
df
# Out:
#                                                 title  \
# 0                                   Backend Developer
# 1                 Fullstack Web Application Developer
# 2                   Software Engineer (Python/Django)
# 3                              Website Administrative
# 4   Software Engineering Manager (ISW Principal En...
# 5                      Web Development Coding Teacher
# 6                                Full Stack Developer
# 7           Data Collection and Data Entry Specialist
# 8                   Business Systems Integration Lead
# 9   Developer - Software Development.Information T...
# 10              Data Scientist.Enterprise Business NG
# 11                                              CTA 2
# 12                    Quality Assurance (QA) Engineer
# 13                      Data Science Tutor/Instructor
# 14                                   Business Analyst
# 15                                Senior Data Analyst
#
#                                           description  \
# 0   As a full backend developer for websites and a...
# 1   We seek to hire a suitable candidate to fill t...
# 2   We are looking for a talented Python/Django ba...
# 3   Our client is looking to hire a suitable candi...
# 4   Our client is looking to hire a suitable candi...
# 5   We are looking to hire a suitable candidate to...
# 6   A reputable tech startup is seeking to employ ...
# 7   We are currently seeking a dedicated and detai...
# 8   Collabora is looking for an experienced Busine...
# 9
# 10
# 11
# 12  Join a venture-backed company revolutionizing ...
# 13  We are seeking a dynamic and experienced Data ...
# 14  We’re continuously on the hunt for talented Bu...
# 15  At iVisa we believe that traveling should be s...
#
#                                           requirement  \
# 0         Minimum of 2 -3 years of working experience
# 1   Good knowledge and experience in Node.js with ...
# 2                       2 years of working experience
# 3                      3 years of working experience.
# 4   Wide and deep experience providing expert comp...
# 5   Must be able to instruct students of varying s...
# 6   At least two years of experience in building l...
# 7   Proven experience in data collection and data ...
# 8                   Coaching and mentoring experience
# 9
# 10
# 11
# 12  Minimum of 5 years of proven work experience a...
# 13  Proficiency in Python and experience with the ...
# 14
# 15  4+ years of experience working with Google Ana...
#
#                    job_type                          industry  \
# 0   Remote (Work From Home)  \nBanking, Finance & Insurance\n
# 1                     Lagos                 \nIT & Telecoms\n
# 2   Remote (Work From Home)                 \nIT & Telecoms\n
# 3                     Lagos                   \nReal Estate\n
# 4                     Lagos  \nBanking, Finance & Insurance\n
# 5                     Abuja                     \nEducation\n
# 6                     Abuja                     \nEducation\n
# 7   Remote (Work From Home)                 \nIT & Telecoms\n
# 8   Remote (Work From Home)                 \nIT & Telecoms\n
# 9                     Lagos                   \nUnspecified\n
# 10                    Lagos                   \nUnspecified\n
# 11                    Lagos                   \nUnspecified\n
# 12  Remote (Work From Home)                 \nIT & Telecoms\n
# 13                    Lagos                     \nEducation\n
# 14  Remote (Work From Home)                 \nIT & Telecoms\n
# 15  Remote (Work From Home)                 \nIT & Telecoms\n
#
#                       salary
# 0        NGN\n\nConfidential
# 1   NGN\n\n250,000 - 400,000
# 2   NGN\n\n250,000 - 400,000
# 3        NGN\n\nConfidential
# 4        NGN\n\nConfidential
# 5   NGN\n\n150,000 - 250,000
# 6   NGN\n\n250,000 - 400,000
# 7    NGN\n\n75,000 - 150,000
# 8        NGN\n\nConfidential
# 9        NGN\n\nConfidential
# 10       NGN\n\nConfidential
# 11       NGN\n\nConfidential
# 12  NGN\n\n250,000 - 400,000
# 13   NGN\n\n75,000 - 150,000
# 14       NGN\n\nConfidential
# 15       NGN\n\nConfidential

# %%
# Scraping through different pages
# Function to extract Product Title
# ... (your function definitions go here) ...

if __name__ == '__main__':
    
    #add your headers
    HEADERS = ({'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/119.0', 'Accept-Language':'en-US, en;q=0.5'})
    
    #define your url
    URL = "https://www.jobberman.com/jobs/software-data?sort=featured&page="
    
    #create an empty dataframe to store details
    d = {"title":[], "description":[], "requirement":[], "job_type":[], "industry":[], "salary":[]}

    # Loop over the pages
    for page in range(1, 17):
        webpage = requests.get(URL + str(page), headers=HEADERS)
        soup = BeautifulSoup(webpage.content, "html.parser")
        links = soup.find_all("a", attrs={'class':'relative mb-3 text-lg font-medium break-words focus:outline-none metrics-apply-now text-link-500 text-loading-animate'})
        links_list = []
        
        #Loop for extracting links from link list
        for link in links:
            links_list.append(link.get('href'))

        
        #Loop for extracting all job details from each link
        for link in links_list:
            new_webpage = requests.get(link, headers=HEADERS)
            new_soup = BeautifulSoup(new_webpage.content, "html.parser")
            
            #Functions to dislay all job details
            d['title'].append(get_title(new_soup))
            d['description'].append(get_description(new_soup))
            d['requirement'].append(get_requirement(new_soup))
            d['job_type'].append(get_job_type(new_soup))
            d['industry'].append(get_industry(new_soup))
            d['salary'].append(get_salary(new_soup))

    df = pd.DataFrame.from_dict(d)
    df['title'].replace('', np.nan, inplace=True)
    df = df.dropna(subset=['title'])
    df.to_csv("jobberman_data.csv", header=True, index=False)

# %%
df
# Out:
#                                                  title  \
# 0                                    Backend Developer
# 1                  Fullstack Web Application Developer
# 2                    Software Engineer (Python/Django)
# 3                               Website Administrative
# 4    Software Engineering Manager (ISW Principal En...
# ..                                                 ...
# 246                        Technology Lead for Nigeria
# 247                 Data Engineer â VerifyMe Nigeria
# 248   Enterprise Architect for an MNC in Lagos Nigeria
# 249  Backend Engineer Graduate Trainee â Zojatech...
# 250                   SharePoint Application Developer
#
#                                            description  \
# 0    As a full backend developer for websites and a...
# 1    We seek to hire a suitable candidate to fill t...
# 2    We are looking for a talented Python/Django ba...
# 3    Our client is looking to hire a suitable candi...
# 4    Our client is looking to hire a suitable candi...
# ..                                                 ...
# 246
# 247
# 248
# 249
# 250
#
#                                            requirement  \
# 0          Minimum of 2 -3 years of working experience
# 1    Good knowledge and experience in Node.js with ...
# 2                        2 years of working experience
# 3                       3 years of working experience.
# 4    Wide and deep experience providing expert comp...
# ..                                                 ...
# 246
# 247   Must have experience with native AWS technolo...
# 248
# 249   Candidates should possess a Bachelorâs Degr...
# 250  Minimum 5 years experience in supporting and m...
#
#                     job_type                      industry  \
# 0    Remote (Work From Home)  Banking, Finance & Insurance
# 1                      Lagos                 IT & Telecoms
# 2    Remote (Work From Home)                 IT & Telecoms
# 3                      Lagos                   Real Estate
# 4                      Lagos  Banking, Finance & Insurance
# ..                       ...                           ...
# 246          Rest of Nigeria                   Unspecified
# 247                    Lagos                   Unspecified
# 248          Rest of Nigeria                   Unspecified
# 249                    Lagos                   Unspecified
# 250                    Lagos                  Construction
#
#                        salary
# 0         NGN\n\nConfidential
# 1    NGN\n\n250,000 - 400,000
# 2    NGN\n\n250,000 - 400,000
# 3         NGN\n\nConfidential
# 4         NGN\n\nConfidential
# ..                        ...
# 246       NGN\n\nConfidential
# 247       NGN\n\nConfidential
# 248       NGN\n\nConfidential
# 249       NGN\n\nConfidential
# 250       NGN\n\nConfidential
#
# [251 rows x 6 columns]

# %%
df.to_csv(r"C:\Users\Olamilekan .A. David\Downloads\jobberman_data.csv", index=False)

# %%
df.to_excel(r"C:\Users\Olamilekan .A. David\Downloads\jobberman_data.xlsx", index=False)
